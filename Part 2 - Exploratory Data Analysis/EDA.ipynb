# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# Data - https://github.com/LuisM78/Appliances-energy-prediction-data

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import datetime
import calendar
import numpy as np 
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from matplotlib.pylab import rcParams
import seaborn as sns

# %% [markdown]
# Reading the csv file

# %%
f=pd.read_csv("C:/Users/nitin/Documents/NEU/SEM 2/ADS/Assignment 2/Appliances-energy-prediction-data-master/energydata_complete.csv")

# %% [markdown]
# Let's check what's inside the file.

# %%
f
# Out:
#                   date  Appliances  lights         T1       RH_1         T2  \
# 0      1/11/2016 17:00          60      30  19.890000  47.596667  19.200000
# 1      1/11/2016 17:10          60      30  19.890000  46.693333  19.200000
# 2      1/11/2016 17:20          50      30  19.890000  46.300000  19.200000
# 3      1/11/2016 17:30          50      40  19.890000  46.066667  19.200000
# 4      1/11/2016 17:40          60      40  19.890000  46.333333  19.200000
# 5      1/11/2016 17:50          50      40  19.890000  46.026667  19.200000
# 6      1/11/2016 18:00          60      50  19.890000  45.766667  19.200000
# 7      1/11/2016 18:10          60      50  19.856667  45.560000  19.200000
# 8      1/11/2016 18:20          60      40  19.790000  45.597500  19.200000
# 9      1/11/2016 18:30          70      40  19.856667  46.090000  19.230000
# 10     1/11/2016 18:40         230      70  19.926667  45.863333  19.356667
# ...

# %% [markdown]
# Finding the dimension of the file

# %%
f.shape
# Out:
# (19735, 29)

# %% [markdown]
# So, the data has 29 columns and 19,735 rows full of data. But does it has any null vales?

# %%
f.isnull().sum()
# Out:
# date           0
# Appliances     0
# lights         0
# T1             0
# RH_1           0
# T2             0
# RH_2           0
# T3             0
# RH_3           0
# T4             0
# RH_4           0
# T5             0
# RH_5           0
# T6             0
# RH_6           0
# T7             0
# RH_7           0
# T8             0
# RH_8           0
# T9             0
# RH_9           0
# T_out          0
# Press_mm_hg    0
# RH_out         0
# Windspeed      0
# Visibility     0
# Tdewpoint      0
# rv1            0
# rv2            0
# dtype: int64

# %% [markdown]
# The csv file does not have any null values. But we have to checkk the format of the file to understand what type of values does it contain.

# %%
f.dtypes
# Out:
# date            object
# Appliances       int64
# lights           int64
# T1             float64
# RH_1           float64
# T2             float64
# RH_2           float64
# T3             float64
# RH_3           float64
# T4             float64
# RH_4           float64
# T5             float64
# RH_5           float64
# T6             float64
# RH_6           float64
# T7             float64
# RH_7           float64
# T8             float64
# RH_8           float64
# T9             float64
# RH_9           float64
# T_out          float64
# Press_mm_hg    float64
# RH_out         float64
# Windspeed      float64
# Visibility     float64
# Tdewpoint      float64
# rv1            float64
# rv2            float64
# dtype: object

# %% [markdown]
# All values are in 'float'. This is easy for us when we are doing calculations

# %% [markdown]
# Let's distinguish the data and make summary matrix which would help us understand the data better

# %%
import pandas as pd
import datetime
import calendar
f=pd.read_csv("C:/Users/nitin/Documents/NEU/SEM 2/ADS/Assignment 2/Appliances-energy-prediction-data-master/energydata_complete.csv")
f['date']=pd.to_datetime(f['date'])
f['year']=f['date'].dt.year
f['month']=f['date'].dt.month
f['day']=f['date'].dt.day
f['day_of_week']=f['date'].dt.weekday_name
f['time_hr_24']=f['date'].dt.hour
morning=range(6,12)
afternoon=range(12,17)
evening=range(17,22)
def time_slot(x):
    if x in morning:
        return 'morning'
    elif x in afternoon:
        return 'afternoon'
    elif x in evening:
        return 'evening'
    else:
        return 'night'
    
f['time_slot']=f['time_hr_24'].map(time_slot)

week1=range(1,8)
week2=range(8,15)
week3=range(15,22)
week4=range(22,29)

def week_num(x):
    if x in week1:
        return 'week1'
    elif x in week2:
        return 'week2'
    elif x in week3:
        return 'week3'
    elif x in week4:
        return 'week4'
    else:
        return 'week5' 
f['week']=f['day'].map(week_num)
weekend = ['Saturday','Sunday']
def week_day_type(x):
    if x in weekend:
        return 'weekends'
    else:
        return 'weekdays'
f['week_day_type']=f['day_of_week'].map(week_day_type)
    
f.dtypes
all_df_dict={df : f[f['month']==df] for df in f['month'].unique()}
all_df_dict
df_summ=pd.DataFrame(columns=['Month','Tot_Appliance','Avg_Appliance','Tot_light','Avg_light','Tot_Energy','Avg_Energy',
                             'Mean_T1','Mean_RH_1','Mean_T2','Mean_RH_2','Mean_T3','Mean_RH_3',
                             'Mean_T4','Mean_RH_4','Mean_T5','Mean_RH_5','Mean_T6','Mean_RH_6',
                             'Mean_T7','Mean_RH_7','Mean_T8','Mean_RH_8','Mean_T9','Mean_RH_9',
                             'Mean_T_out','Mean_Press_mm_hg','Mean_RH_out','Mean_Windspeed','Mean_Visibility','Mean_Tdewpoint',
                             'Tot_Morning_App','Mean_Morning_App','Tot_Afternoon_App','Mean_Afternoon_App','Tot_Evening_App',
                             'Mean_Evening_App','Tot_Night_App','Mean_Night_App','Tot_Morning_light','Mean_Morning_light',
                             'Tot_Afternoon_light','Mean_Afternoon_light','Tot_Evening_light','Mean_Evening_light',
                             'Tot_Night_light','Mean_Night_light',
                              
                             'Morn_Mean_T1','Morn_Mean_RH_1','Morn_Mean_T2','Morn_Mean_RH_2','Morn_Mean_T3',
                             'Morn_Mean_RH_3','Morn_Mean_T4','Morn_Mean_RH_4','Morn_Mean_T5','Morn_Mean_RH_5','Morn_Mean_T6','Morn_Mean_RH_6',
                             'Morn_Mean_T7','Morn_Mean_RH_7','Morn_Mean_T8','Morn_Mean_RH_8','Morn_Mean_T9','Morn_Mean_RH_9',
                             'Morn_Mean_T_out','Morn_Mean_Press_mm_hg','Morn_Mean_RH_out','Morn_Mean_Windspeed',
                             'Morn_Mean_Visibility','Morn_Mean_Tdewpoint',
                             
                             'After_Mean_T1','After_Mean_RH_1','After_Mean_T2','After_Mean_RH_2','After_Mean_T3',
                             'After_Mean_RH_3','After_Mean_T4','After_Mean_RH_4','After_Mean_T5','After_Mean_RH_5','After_Mean_T6',
                             'After_Mean_RH_6','After_Mean_T7','After_Mean_RH_7','After_Mean_T8','After_Mean_RH_8','After_Mean_T9',
                             'After_Mean_RH_9','After_Mean_T_out','After_Mean_Press_mm_hg','After_Mean_RH_out','After_Mean_Windspeed',
                             'After_Mean_Visibility','After_Mean_Tdewpoint',
                             
                             'Eve_Mean_T1','Eve_Mean_RH_1','Eve_Mean_T2','Eve_Mean_RH_2','Eve_Mean_T3','Eve_Mean_RH_3',
                             'Eve_Mean_T4','Eve_Mean_RH_4','Eve_Mean_T5','Eve_Mean_RH_5','Eve_Mean_T6','Eve_Mean_RH_6',
                             'Eve_Mean_T7','Eve_Mean_RH_7','Eve_Mean_T8','Eve_Mean_RH_8','Eve_Mean_T9','Eve_Mean_RH_9',
                             'Eve_Mean_T_out','Eve_Mean_Press_mm_hg','Eve_Mean_RH_out','Eve_Mean_Windspeed','Eve_Mean_Visibility',
                             'Eve_Mean_Tdewpoint',
                             
                             'Night_Mean_T1','Night_Mean_RH_1','Night_Mean_T2','Night_Mean_RH_2','Night_Mean_T3',
                             'Night_Mean_RH_3','Night_Mean_T4','Night_Mean_RH_4','Night_Mean_T5','Night_Mean_RH_5','Night_Mean_T6',
                             'Night_Mean_RH_6','Night_Mean_T7','Night_Mean_RH_7','Night_Mean_T8','Night_Mean_RH_8','Night_Mean_T9',
                             'Night_Mean_RH_9','Night_Mean_T_out','Night_Mean_Press_mm_hg','Night_Mean_RH_out','Night_Mean_Windspeed',
                             'Night_Mean_Visibility','Night_Mean_Tdewpoint',
                             
                             'Week1_Tot_Appliance','Week1_Avg_Appliance','Week1_Tot_light','Week1_Avg_light',
                             'Week1_Mean_T1','Week1_Mean_RH_1','Week1_Night_Mean_T2','Week1_Night_Mean_RH_2','Week1_Night_Mean_T3',
                             'Week1_Mean_RH_3','Week1_Mean_T4','Week1_Mean_RH_4','Week1_Mean_T5','Week1_Mean_RH_5','Week1_Mean_T6',
                             'Week1_Mean_RH_6','Week1_Mean_T7','Week1_Mean_RH_7','Week1_Mean_T8','Week1_Mean_RH_8','Week1_Mean_T9',
                             'Week1_Mean_RH_9','Week1_Mean_T_out','Week1_Mean_Press_mm_hg','Week1_Mean_RH_out','Week1_Mean_Windspeed',
                             'Week1_Mean_Visibility','Week1_Mean_Tdewpoint',
                             
                             'Week2_Tot_Appliance','Week2_Avg_Appliance','Week2_Tot_light','Week2_Avg_light',
                             'Week2_Mean_T1','Week2_Mean_RH_1','Week2_Night_Mean_T2','Week2_Night_Mean_RH_2','Week2_Night_Mean_T3',
                             'Week2_Mean_RH_3','Week2_Mean_T4','Week2_Mean_RH_4','Week2_Mean_T5','Week2_Mean_RH_5','Week2_Mean_T6',
                             'Week2_Mean_RH_6','Week2_Mean_T7','Week2_Mean_RH_7','Week2_Mean_T8','Week2_Mean_RH_8','Week2_Mean_T9',
                             'Week2_Mean_RH_9','Week2_Mean_T_out','Week2_Mean_Press_mm_hg','Week2_Mean_RH_out','Week2_Mean_Windspeed',
                             'Week2_Mean_Visibility','Week2_Mean_Tdewpoint',
                              
                             'Week3_Tot_Appliance','Week3_Avg_Appliance','Week3_Tot_light','Week3_Avg_light',
                             'Week3_Mean_T1','Week3_Mean_RH_1','Week3_Night_Mean_T2','Week3_Night_Mean_RH_2','Week3_Night_Mean_T3',
                             'Week3_Mean_RH_3','Week3_Mean_T4','Week3_Mean_RH_4','Week3_Mean_T5','Week3_Mean_RH_5','Week3_Mean_T6',
                             'Week3_Mean_RH_6','Week3_Mean_T7','Week3_Mean_RH_7','Week3_Mean_T8','Week3_Mean_RH_8','Week3_Mean_T9',
                             'Week3_Mean_RH_9','Week3_Mean_T_out','Week3_Mean_Press_mm_hg','Week3_Mean_RH_out','Week3_Mean_Windspeed',
                             'Week3_Mean_Visibility','Week3_Mean_Tdewpoint',
                              
                             'Week4_Tot_Appliance','Week4_Avg_Appliance','Week4_Tot_light','Week4_Avg_light',
                             'Week4_Mean_T1','Week4_Mean_RH_1','Week4_Night_Mean_T2','Week4_Night_Mean_RH_2','Week4_Night_Mean_T3',
                             'Week4_Mean_RH_3','Week4_Mean_T4','Week4_Mean_RH_4','Week4_Mean_T5','Week4_Mean_RH_5','Week4_Mean_T6',
                             'Week4_Mean_RH_6','Week4_Mean_T7','Week4_Mean_RH_7','Week4_Mean_T8','Week4_Mean_RH_8','Week4_Mean_T9',
                             'Week4_Mean_RH_9','Week4_Mean_T_out','Week4_Mean_Press_mm_hg','Week4_Mean_RH_out','Week4_Mean_Windspeed',
                             'Week4_Mean_Visibility','Week4_Mean_Tdewpoint',
                              
                             'Week5_Tot_Appliance','Week5_Avg_Appliance','Week5_Tot_light','Week5_Avg_light',
                             'Week5_Mean_T1','Week5_Mean_RH_1','Week5_Night_Mean_T2','Week5_Night_Mean_RH_2','Week5_Night_Mean_T3',
                             'Week5_Mean_RH_3','Week5_Mean_T4','Week5_Mean_RH_4','Week5_Mean_T5','Week5_Mean_RH_5','Week5_Mean_T6',
                             'Week5_Mean_RH_6','Week5_Mean_T7','Week5_Mean_RH_7','Week5_Mean_T8','Week5_Mean_RH_8','Week5_Mean_T9',
                             'Week5_Mean_RH_9','Week5_Mean_T_out','Week5_Mean_Press_mm_hg','Week5_Mean_RH_out','Week5_Mean_Windspeed',
                             'Week5_Mean_Visibility','Week5_Mean_Tdewpoint',
                             
                             'Weekdays_Tot_Appliance','Weekdays_Avg_Appliance','Weekdays_Tot_light','Weekdays_Avg_light',
                             'Weekdays_Mean_T1','Weekdays_Mean_RH_1','Weekdays_Night_Mean_T2','Weekdays_Night_Mean_RH_2','Weekdays_Night_Mean_T3',
                             'Weekdays_Mean_RH_3','Weekdays_Mean_T4','Weekdays_Mean_RH_4','Weekdays_Mean_T5','Weekdays_Mean_RH_5','Weekdays_Mean_T6',
                             'Weekdays_Mean_RH_6','Weekdays_Mean_T7','Weekdays_Mean_RH_7','Weekdays_Mean_T8','Weekdays_Mean_RH_8','Weekdays_Mean_T9',
                             'Weekdays_Mean_RH_9','Weekdays_Mean_T_out','Weekdays_Mean_Press_mm_hg','Weekdays_Mean_RH_out','Weekdays_Mean_Windspeed',
                             'Weekdays_Mean_Visibility','Weekdays_Mean_Tdewpoint',
                             
                             'Weekends_Tot_Appliance','Weekends_Avg_Appliance','Weekends_Tot_light','Weekends_Avg_light',
                             'Weekends_Mean_T1','Weekends_Mean_RH_1','Weekends_Night_Mean_T2','Weekends_Night_Mean_RH_2','Weekends_Night_Mean_T3',
                             'Weekends_Mean_RH_3','Weekends_Mean_T4','Weekends_Mean_RH_4','Weekends_Mean_T5','Weekends_Mean_RH_5','Weekends_Mean_T6',
                             'Weekends_Mean_RH_6','Weekends_Mean_T7','Weekends_Mean_RH_7','Weekends_Mean_T8','Weekends_Mean_RH_8','Weekends_Mean_T9',
                             'Weekends_Mean_RH_9','Weekends_Mean_T_out','Weekends_Mean_Press_mm_hg','Weekends_Mean_RH_out','Weekends_Mean_Windspeed',
                             'Weekends_Mean_Visibility','Weekends_Mean_Tdewpoint'])
df_min_max_summ=pd.DataFrame(columns=['Month','Max_App','Max_light',
                                      'Max_T1','Max_RH_1','Max_T2','Max_RH_2','Max_T3','Max_RH_3',
                                      'Max_T4','Max_RH_4','Max_T5','Max_RH_5','Max_T6','Max_RH_6',
                                      'Max_T7','Max_RH_7','Max_T8','Max_RH_8','Max_T9','Max_RH_9','Max_T_out',
                                      'Max_Press_mm_hg','Max_RH_out','Max_Windspeed','Max_Visibility','Max_Tdewpoint',
                                      
                                      'Min_App','Min_light',
                                      'Min_T1','Min_RH_1','Min_T2','Min_RH_2','Min_T3','Min_RH_3',
                                      'Min_T4','Min_RH_4','Min_T5','Min_RH_5','Min_T6','Min_RH_6',
                                      'Min_T7','Min_RH_7','Min_T8','Min_RH_8','Min_T9','Min_RH_9','Min_T_out',
                                      'Min_Press_mm_hg','Min_RH_out','Min_Windspeed','Min_Visibility','Min_Tdewpoint',
                                      
                                      'Week1_Max_App','Week1_Max_light',
                                      'Week1_Max_T1','Week1_Max_RH_1','Week1_Max_T2','Week1_Max_RH_2','Week1_Max_T3','Week1_Max_RH_3',
                                      'Week1_Max_T4','Week1_Max_RH_4','Week1_Max_T5','Week1_Max_RH_5','Week1_Max_T6','Week1_Max_RH_6',
                                      'Week1_Max_T7','Week1_Max_RH_7','Week1_Max_T8','Week1_Max_RH_8','Week1_Max_T9','Week1_Max_RH_9','Week1_Max_T_out',
                                      'Week1_Max_Press_mm_hg','Week1_Max_RH_out','Week1_Max_Windspeed','Week1_Max_Visibility','Week1_Max_Tdewpoint',
                                      'Week1_Min_App','Week1_Min_light',
                                      'Week1_Min_T1','Week1_Min_RH_1','Week1_Min_T2','Week1_Min_RH_2','Week1_Min_T3','Week1_Min_RH_3',
                                      'Week1_Min_T4','Week1_Min_RH_4','Week1_Min_T5','Week1_Min_RH_5','Week1_Min_T6','Week1_Min_RH_6',
                                      'Week1_Min_T7','Week1_Min_RH_7','Week1_Min_T8','Week1_Min_RH_8','Week1_Min_T9','Week1_Min_RH_9','Week1_Min_T_out',
                                      'Week1_Min_Press_mm_hg','Week1_Min_RH_out','Week1_Min_Windspeed','Week1_Min_Visibility','Week1_Min_Tdewpoint',
                                      
                                      'Week2_Max_App','Week2_Max_light',
                                      'Week2_Max_T1','Week2_Max_RH_1','Week2_Max_T2','Week2_Max_RH_2','Week2_Max_T3','Week2_Max_RH_3',
                                      'Week2_Max_T4','Week2_Max_RH_4','Week2_Max_T5','Week2_Max_RH_5','Week2_Max_T6','Week2_Max_RH_6',
                                      'Week2_Max_T7','Week2_Max_RH_7','Week2_Max_T8','Week2_Max_RH_8','Week2_Max_T9','Week2_Max_RH_9','Week2_Max_T_out',
                                      'Week2_Max_Press_mm_hg','Week2_Max_RH_out','Week2_Max_Windspeed','Week2_Max_Visibility','Week2_Max_Tdewpoint',
                                      'Week2_Min_App','Week2_Min_light',
                                      'Week2_Min_T1','Week2_Min_RH_1','Week2_Min_T2','Week2_Min_RH_2','Week2_Min_T3','Week2_Min_RH_3',
                                      'Week2_Min_T4','Week2_Min_RH_4','Week2_Min_T5','Week2_Min_RH_5','Week2_Min_T6','Week2_Min_RH_6',
                                      'Week2_Min_T7','Week2_Min_RH_7','Week2_Min_T8','Week2_Min_RH_8','Week2_Min_T9','Week2_Min_RH_9','Week2_Min_T_out',
                                      'Week2_Min_Press_mm_hg','Week2_Min_RH_out','Week2_Min_Windspeed','Week2_Min_Visibility','Week2_Min_Tdewpoint',
                                      
                                      'Week3_Max_App','Week3_Max_light',
                                      'Week3_Max_T1','Week3_Max_RH_1','Week3_Max_T2','Week3_Max_RH_2','Week3_Max_T3','Week3_Max_RH_3',
                                      'Week3_Max_T4','Week3_Max_RH_4','Week3_Max_T5','Week3_Max_RH_5','Week3_Max_T6','Week3_Max_RH_6',
                                      'Week3_Max_T7','Week3_Max_RH_7','Week3_Max_T8','Week3_Max_RH_8','Week3_Max_T9','Week3_Max_RH_9','Week3_Max_T_out',
                                      'Week3_Max_Press_mm_hg','Week3_Max_RH_out','Week3_Max_Windspeed','Week3_Max_Visibility','Week3_Max_Tdewpoint',
                                      'Week3_Min_App','Week3_Min_light',
                                      'Week3_Min_T1','Week3_Min_RH_1','Week3_Min_T2','Week3_Min_RH_2','Week3_Min_T3','Week3_Min_RH_3',
                                      'Week3_Min_T4','Week3_Min_RH_4','Week3_Min_T5','Week3_Min_RH_5','Week3_Min_T6','Week3_Min_RH_6',
                                      'Week3_Min_T7','Week3_Min_RH_7','Week3_Min_T8','Week3_Min_RH_8','Week3_Min_T9','Week3_Min_RH_9','Week3_Min_T_out',
                                      'Week3_Min_Press_mm_hg','Week3_Min_RH_out','Week3_Min_Windspeed','Week3_Min_Visibility','Week3_Min_Tdewpoint',
                                      
                                      'Week4_Max_App','Week4_Max_light',
                                      'Week4_Max_T1','Week4_Max_RH_1','Week4_Max_T2','Week4_Max_RH_2','Week4_Max_T3','Week4_Max_RH_3',
                                      'Week4_Max_T4','Week4_Max_RH_4','Week4_Max_T5','Week4_Max_RH_5','Week4_Max_T6','Week4_Max_RH_6',
                                      'Week4_Max_T7','Week4_Max_RH_7','Week4_Max_T8','Week4_Max_RH_8','Week4_Max_T9','Week4_Max_RH_9','Week4_Max_T_out',
                                      'Week4_Max_Press_mm_hg','Week4_Max_RH_out','Week4_Max_Windspeed','Week4_Max_Visibility','Week4_Max_Tdewpoint',
                                      'Week4_Min_App','Week4_Min_light',
                                      'Week4_Min_T1','Week4_Min_RH_1','Week4_Min_T2','Week4_Min_RH_2','Week4_Min_T3','Week4_Min_RH_3',
                                      'Week4_Min_T4','Week4_Min_RH_4','Week4_Min_T5','Week4_Min_RH_5','Week4_Min_T6','Week4_Min_RH_6',
                                      'Week4_Min_T7','Week4_Min_RH_7','Week4_Min_T8','Week4_Min_RH_8','Week4_Min_T9','Week4_Min_RH_9','Week4_Min_T_out',
                                      'Week4_Min_Press_mm_hg','Week4_Min_RH_out','Week4_Min_Windspeed','Week4_Min_Visibility','Week4_Min_Tdewpoint',
                                      
                                      'Week5_Max_App','Week5_Max_light',
                                      'Week5_Max_T1','Week5_Max_RH_1','Week5_Max_T2','Week5_Max_RH_2','Week5_Max_T3','Week5_Max_RH_3',
                                      'Week5_Max_T4','Week5_Max_RH_4','Week5_Max_T5','Week5_Max_RH_5','Week5_Max_T6','Week5_Max_RH_6',
                                      'Week5_Max_T7','Week5_Max_RH_7','Week5_Max_T8','Week5_Max_RH_8','Week5_Max_T9','Week5_Max_RH_9','Week5_Max_T_out',
                                      'Week5_Max_Press_mm_hg','Week5_Max_RH_out','Week5_Max_Windspeed','Week5_Max_Visibility','Week5_Max_Tdewpoint',
                                      'Week5_Min_App','Week5_Min_light',
                                      'Week5_Min_T1','Week5_Min_RH_1','Week5_Min_T2','Week5_Min_RH_2','Week5_Min_T3','Week5_Min_RH_3',
                                      'Week5_Min_T4','Week5_Min_RH_4','Week5_Min_T5','Week5_Min_RH_5','Week5_Min_T6','Week5_Min_RH_6',
                                      'Week5_Min_T7','Week5_Min_RH_7','Week5_Min_T8','Week5_Min_RH_8','Week5_Min_T9','Week5_Min_RH_9','Week5_Min_T_out',
                                      'Week5_Min_Press_mm_hg','Week5_Min_RH_out','Week5_Min_Windspeed','Week5_Min_Visibility','Week5_Min_Tdewpoint'
                                      ])

for key, val in all_df_dict.items():
    df=all_df_dict[key]
    moth=calendar.month_abbr[key]
    Tot_Appliance=df['Appliances'].sum()
    Avg_Appliance=df['Appliances'].mean(axis=0)
    Tot_light=df['lights'].sum()
    Avg_light=df['lights'].mean(axis=0)
    Tot_Energy=Tot_Appliance+Tot_light
    Avg_Energy=Avg_Appliance+Avg_light
    Mean_T1=df['T1'].mean(axis=0)
    Mean_RH_1=df['RH_1'].mean(axis=0)
    Mean_T2=df['T2'].mean(axis=0)
    Mean_RH_2=df['RH_2'].mean(axis=0)
    Mean_T3=df['T3'].mean(axis=0)
    Mean_RH_3=df['RH_3'].mean(axis=0)
    Mean_T4=df['T4'].mean(axis=0)
    Mean_RH_4=df['RH_4'].mean(axis=0)
    Mean_T5=df['T5'].mean(axis=0)
    Mean_RH_5=df['RH_5'].mean(axis=0)
    Mean_T6=df['T6'].mean(axis=0)
    Mean_RH_6=df['RH_6'].mean(axis=0)
    Mean_T7=df['T7'].mean(axis=0)
    Mean_RH_7=df['RH_7'].mean(axis=0)
    Mean_T8=df['T8'].mean(axis=0)
    Mean_RH_8=df['RH_8'].mean(axis=0)
    Mean_T9=df['T9'].mean(axis=0)
    Mean_RH_9=df['RH_9'].mean(axis=0)
    Mean_T_out=df['T_out'].mean(axis=0)
    Mean_Press_mm_hg=df['Press_mm_hg'].mean(axis=0)
    Mean_RH_out=df['RH_out'].mean(axis=0)
    Mean_Windspeed=df['Windspeed'].mean(axis=0)
    Mean_Visibility=df['Visibility'].mean(axis=0)
    Mean_Tdewpoint=df['Tdewpoint'].mean(axis=0)
    
    Tot_Morning_App=df[df['time_slot']=='morning']['Appliances'].sum()
    Mean_Morning_App=df[df['time_slot']=='morning']['Appliances'].mean()
    Tot_Afternoon_App=df[df['time_slot']=='afternoon']['Appliances'].sum()
    Mean_Afternoon_App=df[df['time_slot']=='afternoon']['Appliances'].mean()
    Tot_Evening_App=df[df['time_slot']=='evening']['Appliances'].sum()
    Mean_Evening_App=df[df['time_slot']=='evening']['Appliances'].mean()
    Tot_Night_App=df[df['time_slot']=='night']['Appliances'].sum()
    Mean_Night_App=df[df['time_slot']=='night']['Appliances'].mean()
    
    Tot_Morning_light=df[df['time_slot']=='morning']['lights'].sum()
    Mean_Morning_light=df[df['time_slot']=='morning']['lights'].mean()
    Tot_Afternoon_light=df[df['time_slot']=='afternoon']['lights'].sum()
    Mean_Afternoon_light=df[df['time_slot']=='afternoon']['lights'].mean()
    Tot_Evening_light=df[df['time_slot']=='evening']['lights'].sum()
    Mean_Evening_light=df[df['time_slot']=='evening']['lights'].mean()
    Tot_Night_light=df[df['time_slot']=='night']['lights'].sum()
    Mean_Night_light=df[df['time_slot']=='night']['lights'].mean()
    
    Morn_Mean_T1=df[df['time_slot']=='morning']['T1'].mean(axis=0)
    Morn_Mean_RH_1=df[df['time_slot']=='morning']['RH_1'].mean(axis=0)
    Morn_Mean_T2=df[df['time_slot']=='morning']['T2'].mean(axis=0)
    Morn_Mean_RH_2=df[df['time_slot']=='morning']['RH_2'].mean(axis=0)
    Morn_Mean_T3=df[df['time_slot']=='morning']['T3'].mean(axis=0)
    Morn_Mean_RH_3=df[df['time_slot']=='morning']['RH_3'].mean(axis=0)
    Morn_Mean_T4=df[df['time_slot']=='morning']['T4'].mean(axis=0)
    Morn_Mean_RH_4=df[df['time_slot']=='morning']['RH_4'].mean(axis=0)
    Morn_Mean_T5=df[df['time_slot']=='morning']['T5'].mean(axis=0)
    Morn_Mean_RH_5=df[df['time_slot']=='morning']['RH_5'].mean(axis=0)
    Morn_Mean_T6=df[df['time_slot']=='morning']['T6'].mean(axis=0)
    Morn_Mean_RH_6=df[df['time_slot']=='morning']['RH_6'].mean(axis=0)
    Morn_Mean_T7=df[df['time_slot']=='morning']['T7'].mean(axis=0)
    Morn_Mean_RH_7=df[df['time_slot']=='morning']['RH_7'].mean(axis=0)
    Morn_Mean_T8=df[df['time_slot']=='morning']['T8'].mean(axis=0)
    Morn_Mean_RH_8=df[df['time_slot']=='morning']['RH_8'].mean(axis=0)
    Morn_Mean_T9=df[df['time_slot']=='morning']['T9'].mean(axis=0)
    Morn_Mean_RH_9=df[df['time_slot']=='morning']['RH_9'].mean(axis=0)
    Morn_Mean_T_out=df[df['time_slot']=='morning']['T_out'].mean(axis=0)
    Morn_Mean_Press_mm_hg=df[df['time_slot']=='morning']['Press_mm_hg'].mean(axis=0)
    Morn_Mean_RH_out=df[df['time_slot']=='morning']['RH_out'].mean(axis=0)
    Morn_Mean_Windspeed=df[df['time_slot']=='morning']['Windspeed'].mean(axis=0)
    Morn_Mean_Visibility=df[df['time_slot']=='morning']['Visibility'].mean(axis=0)
    Morn_Mean_Tdewpoint=df[df['time_slot']=='morning']['Tdewpoint'].mean(axis=0)
    
    After_Mean_T1=df[df['time_slot']=='afternoon']['T1'].mean(axis=0)
    After_Mean_RH_1=df[df['time_slot']=='afternoon']['RH_1'].mean(axis=0)
    After_Mean_T2=df[df['time_slot']=='afternoon']['T2'].mean(axis=0)
    After_Mean_RH_2=df[df['time_slot']=='afternoon']['RH_2'].mean(axis=0)
    After_Mean_T3=df[df['time_slot']=='afternoon']['T3'].mean(axis=0)
    After_Mean_RH_3=df[df['time_slot']=='afternoon']['RH_3'].mean(axis=0)
    After_Mean_T4=df[df['time_slot']=='afternoon']['T4'].mean(axis=0)
    After_Mean_RH_4=df[df['time_slot']=='afternoon']['RH_4'].mean(axis=0)
    After_Mean_T5=df[df['time_slot']=='afternoon']['T5'].mean(axis=0)
    After_Mean_RH_5=df[df['time_slot']=='afternoon']['RH_5'].mean(axis=0)
    After_Mean_T6=df[df['time_slot']=='afternoon']['T6'].mean(axis=0)
    After_Mean_RH_6=df[df['time_slot']=='afternoon']['RH_6'].mean(axis=0)
    After_Mean_T7=df[df['time_slot']=='afternoon']['T7'].mean(axis=0)
    After_Mean_RH_7=df[df['time_slot']=='afternoon']['RH_7'].mean(axis=0)
    After_Mean_T8=df[df['time_slot']=='afternoon']['T8'].mean(axis=0)
    After_Mean_RH_8=df[df['time_slot']=='afternoon']['RH_8'].mean(axis=0)
    After_Mean_T9=df[df['time_slot']=='afternoon']['T9'].mean(axis=0)
    After_Mean_RH_9=df[df['time_slot']=='afternoon']['RH_9'].mean(axis=0)
    After_Mean_T_out=df[df['time_slot']=='afternoon']['T_out'].mean(axis=0)
    After_Mean_Press_mm_hg=df[df['time_slot']=='afternoon']['Press_mm_hg'].mean(axis=0)
    After_Mean_RH_out=df[df['time_slot']=='afternoon']['RH_out'].mean(axis=0)
    After_Mean_Windspeed=df[df['time_slot']=='afternoon']['Windspeed'].mean(axis=0)
    After_Mean_Visibility=df[df['time_slot']=='afternoon']['Visibility'].mean(axis=0)
    After_Mean_Tdewpoint=df[df['time_slot']=='afternoon']['Tdewpoint'].mean(axis=0)
    
    Eve_Mean_T1=df[df['time_slot']=='evening']['T1'].mean(axis=0)
    Eve_Mean_RH_1=df[df['time_slot']=='evening']['RH_1'].mean(axis=0)
    Eve_Mean_T2=df[df['time_slot']=='evening']['T2'].mean(axis=0)
    Eve_Mean_RH_2=df[df['time_slot']=='evening']['RH_2'].mean(axis=0)
    Eve_Mean_T3=df[df['time_slot']=='evening']['T3'].mean(axis=0)
    Eve_Mean_RH_3=df[df['time_slot']=='evening']['RH_3'].mean(axis=0)
    Eve_Mean_T4=df[df['time_slot']=='evening']['T4'].mean(axis=0)
    Eve_Mean_RH_4=df[df['time_slot']=='evening']['RH_4'].mean(axis=0)
    Eve_Mean_T5=df[df['time_slot']=='evening']['T5'].mean(axis=0)
    Eve_Mean_RH_5=df[df['time_slot']=='evening']['RH_5'].mean(axis=0)
    Eve_Mean_T6=df[df['time_slot']=='evening']['T6'].mean(axis=0)
    Eve_Mean_RH_6=df[df['time_slot']=='evening']['RH_6'].mean(axis=0)
    Eve_Mean_T7=df[df['time_slot']=='evening']['T7'].mean(axis=0)
    Eve_Mean_RH_7=df[df['time_slot']=='evening']['RH_7'].mean(axis=0)
    Eve_Mean_T8=df[df['time_slot']=='evening']['T8'].mean(axis=0)
    Eve_Mean_RH_8=df[df['time_slot']=='evening']['RH_8'].mean(axis=0)
    Eve_Mean_T9=df[df['time_slot']=='evening']['T9'].mean(axis=0)
    Eve_Mean_RH_9=df[df['time_slot']=='evening']['RH_9'].mean(axis=0)
    Eve_Mean_T_out=df[df['time_slot']=='evening']['T_out'].mean(axis=0)
    Eve_Mean_Press_mm_hg=df[df['time_slot']=='evening']['Press_mm_hg'].mean(axis=0)
    Eve_Mean_RH_out=df[df['time_slot']=='evening']['RH_out'].mean(axis=0)
    Eve_Mean_Windspeed=df[df['time_slot']=='evening']['Windspeed'].mean(axis=0)
    Eve_Mean_Visibility=df[df['time_slot']=='evening']['Visibility'].mean(axis=0)
    Eve_Mean_Tdewpoint=df[df['time_slot']=='evening']['Tdewpoint'].mean(axis=0)
    
    Night_Mean_T1=df[df['time_slot']=='night']['T1'].mean(axis=0)
    Night_Mean_RH_1=df[df['time_slot']=='night']['RH_1'].mean(axis=0)
    Night_Mean_T2=df[df['time_slot']=='night']['T2'].mean(axis=0)
    Night_Mean_RH_2=df[df['time_slot']=='night']['RH_2'].mean(axis=0)
    Night_Mean_T3=df[df['time_slot']=='night']['T3'].mean(axis=0)
    Night_Mean_RH_3=df[df['time_slot']=='night']['RH_3'].mean(axis=0)
    Night_Mean_T4=df[df['time_slot']=='night']['T4'].mean(axis=0)
    Night_Mean_RH_4=df[df['time_slot']=='night']['RH_4'].mean(axis=0)
    Night_Mean_T5=df[df['time_slot']=='night']['T5'].mean(axis=0)
    Night_Mean_RH_5=df[df['time_slot']=='night']['RH_5'].mean(axis=0)
    Night_Mean_T6=df[df['time_slot']=='night']['T6'].mean(axis=0)
    Night_Mean_RH_6=df[df['time_slot']=='night']['RH_6'].mean(axis=0)
    Night_Mean_T7=df[df['time_slot']=='night']['T7'].mean(axis=0)
    Night_Mean_RH_7=df[df['time_slot']=='night']['RH_7'].mean(axis=0)
    Night_Mean_T8=df[df['time_slot']=='night']['T8'].mean(axis=0)
    Night_Mean_RH_8=df[df['time_slot']=='night']['RH_8'].mean(axis=0)
    Night_Mean_T9=df[df['time_slot']=='night']['T9'].mean(axis=0)
    Night_Mean_RH_9=df[df['time_slot']=='night']['RH_9'].mean(axis=0)
    Night_Mean_T_out=df[df['time_slot']=='night']['T_out'].mean(axis=0)
    Night_Mean_Press_mm_hg=df[df['time_slot']=='night']['Press_mm_hg'].mean(axis=0)
    Night_Mean_RH_out=df[df['time_slot']=='night']['RH_out'].mean(axis=0)
    Night_Mean_Windspeed=df[df['time_slot']=='night']['Windspeed'].mean(axis=0)
    Night_Mean_Visibility=df[df['time_slot']=='night']['Visibility'].mean(axis=0)
    Night_Mean_Tdewpoint=df[df['time_slot']=='night']['Tdewpoint'].mean(axis=0)
    
    Week1_Tot_App=df[df['week']=='week1']['Appliances'].sum()
    Week1_Mean_App=df[df['week']=='week1']['Appliances'].mean()
    Week1_Tot_light=df[df['week']=='week1']['lights'].sum()
    Week1_Mean_light=df[df['week']=='week1']['lights'].mean()
    Week1_Mean_T1=df[df['week']=='week1']['T1'].mean(axis=0)
    Week1_Mean_RH_1=df[df['week']=='week1']['RH_1'].mean(axis=0)
    Week1_Mean_T2=df[df['week']=='week1']['T2'].mean(axis=0)
    Week1_Mean_RH_2=df[df['week']=='week1']['RH_2'].mean(axis=0)
    Week1_Mean_T3=df[df['week']=='week1']['T3'].mean(axis=0)
    Week1_Mean_RH_3=df[df['week']=='week1']['RH_3'].mean(axis=0)
    Week1_Mean_T4=df[df['week']=='week1']['T4'].mean(axis=0)
    Week1_Mean_RH_4=df[df['week']=='week1']['RH_4'].mean(axis=0)
    Week1_Mean_T5=df[df['week']=='week1']['T5'].mean(axis=0)
    Week1_Mean_RH_5=df[df['week']=='week1']['RH_5'].mean(axis=0)
    Week1_Mean_T6=df[df['week']=='week1']['T6'].mean(axis=0)
    Week1_Mean_RH_6=df[df['week']=='week1']['RH_6'].mean(axis=0)
    Week1_Mean_T7=df[df['week']=='week1']['T7'].mean(axis=0)
    Week1_Mean_RH_7=df[df['week']=='week1']['RH_7'].mean(axis=0)
    Week1_Mean_T8=df[df['week']=='week1']['T8'].mean(axis=0)
    Week1_Mean_RH_8=df[df['week']=='week1']['RH_8'].mean(axis=0)
    Week1_Mean_T9=df[df['week']=='week1']['T9'].mean(axis=0)
    Week1_Mean_RH_9=df[df['week']=='week1']['RH_9'].mean(axis=0)
    Week1_Mean_T_out=df[df['week']=='week1']['T_out'].mean(axis=0)
    Week1_Mean_Press_mm_hg=df[df['week']=='week1']['Press_mm_hg'].mean(axis=0)
    Week1_Mean_RH_out=df[df['week']=='week1']['RH_out'].mean(axis=0)
    Week1_Mean_Windspeed=df[df['week']=='week1']['Windspeed'].mean(axis=0)
    Week1_Mean_Visibility=df[df['week']=='week1']['Visibility'].mean(axis=0)
    Week1_Mean_Tdewpoint=df[df['week']=='week1']['Tdewpoint'].mean(axis=0)
    
    Week2_Tot_App=df[df['week']=='week2']['Appliances'].sum()
    Week2_Mean_App=df[df['week']=='week2']['Appliances'].mean()
    Week2_Tot_light=df[df['week']=='week2']['lights'].sum()
    Week2_Mean_light=df[df['week']=='week2']['lights'].mean()
    Week2_Mean_T1=df[df['week']=='week2']['T1'].mean(axis=0)
    Week2_Mean_RH_1=df[df['week']=='week2']['RH_1'].mean(axis=0)
    Week2_Mean_T2=df[df['week']=='week2']['T2'].mean(axis=0)
    Week2_Mean_RH_2=df[df['week']=='week2']['RH_2'].mean(axis=0)
    Week2_Mean_T3=df[df['week']=='week2']['T3'].mean(axis=0)
    Week2_Mean_RH_3=df[df['week']=='week2']['RH_3'].mean(axis=0)
    Week2_Mean_T4=df[df['week']=='week2']['T4'].mean(axis=0)
    Week2_Mean_RH_4=df[df['week']=='week2']['RH_4'].mean(axis=0)
    Week2_Mean_T5=df[df['week']=='week2']['T5'].mean(axis=0)
    Week2_Mean_RH_5=df[df['week']=='week2']['RH_5'].mean(axis=0)
    Week2_Mean_T6=df[df['week']=='week2']['T6'].mean(axis=0)
    Week2_Mean_RH_6=df[df['week']=='week2']['RH_6'].mean(axis=0)
    Week2_Mean_T7=df[df['week']=='week2']['T7'].mean(axis=0)
    Week2_Mean_RH_7=df[df['week']=='week2']['RH_7'].mean(axis=0)
    Week2_Mean_T8=df[df['week']=='week2']['T8'].mean(axis=0)
    Week2_Mean_RH_8=df[df['week']=='week2']['RH_8'].mean(axis=0)
    Week2_Mean_T9=df[df['week']=='week2']['T9'].mean(axis=0)
    Week2_Mean_RH_9=df[df['week']=='week2']['RH_9'].mean(axis=0)
    Week2_Mean_T_out=df[df['week']=='week2']['T_out'].mean(axis=0)
    Week2_Mean_Press_mm_hg=df[df['week']=='week2']['Press_mm_hg'].mean(axis=0)
    Week2_Mean_RH_out=df[df['week']=='week2']['RH_out'].mean(axis=0)
    Week2_Mean_Windspeed=df[df['week']=='week2']['Windspeed'].mean(axis=0)
    Week2_Mean_Visibility=df[df['week']=='week2']['Visibility'].mean(axis=0)
    Week2_Mean_Tdewpoint=df[df['week']=='week2']['Tdewpoint'].mean(axis=0)
    
    Week3_Tot_App=df[df['week']=='week3']['Appliances'].sum()
    Week3_Mean_App=df[df['week']=='week3']['Appliances'].mean()
    Week3_Tot_light=df[df['week']=='week3']['lights'].sum()
    Week3_Mean_light=df[df['week']=='week3']['lights'].mean()
    Week3_Mean_T1=df[df['week']=='week3']['T1'].mean(axis=0)
    Week3_Mean_RH_1=df[df['week']=='week3']['RH_1'].mean(axis=0)
    Week3_Mean_T2=df[df['week']=='week3']['T2'].mean(axis=0)
    Week3_Mean_RH_2=df[df['week']=='week3']['RH_2'].mean(axis=0)
    Week3_Mean_T3=df[df['week']=='week3']['T3'].mean(axis=0)
    Week3_Mean_RH_3=df[df['week']=='week3']['RH_3'].mean(axis=0)
    Week3_Mean_T4=df[df['week']=='week3']['T4'].mean(axis=0)
    Week3_Mean_RH_4=df[df['week']=='week3']['RH_4'].mean(axis=0)
    Week3_Mean_T5=df[df['week']=='week3']['T5'].mean(axis=0)
    Week3_Mean_RH_5=df[df['week']=='week3']['RH_5'].mean(axis=0)
    Week3_Mean_T6=df[df['week']=='week3']['T6'].mean(axis=0)
    Week3_Mean_RH_6=df[df['week']=='week3']['RH_6'].mean(axis=0)
    Week3_Mean_T7=df[df['week']=='week3']['T7'].mean(axis=0)
    Week3_Mean_RH_7=df[df['week']=='week3']['RH_7'].mean(axis=0)
    Week3_Mean_T8=df[df['week']=='week3']['T8'].mean(axis=0)
    Week3_Mean_RH_8=df[df['week']=='week3']['RH_8'].mean(axis=0)
    Week3_Mean_T9=df[df['week']=='week3']['T9'].mean(axis=0)
    Week3_Mean_RH_9=df[df['week']=='week3']['RH_9'].mean(axis=0)
    Week3_Mean_T_out=df[df['week']=='week3']['T_out'].mean(axis=0)
    Week3_Mean_Press_mm_hg=df[df['week']=='week3']['Press_mm_hg'].mean(axis=0)
    Week3_Mean_RH_out=df[df['week']=='week3']['RH_out'].mean(axis=0)
    Week3_Mean_Windspeed=df[df['week']=='week3']['Windspeed'].mean(axis=0)
    Week3_Mean_Visibility=df[df['week']=='week3']['Visibility'].mean(axis=0)
    Week3_Mean_Tdewpoint=df[df['week']=='week3']['Tdewpoint'].mean(axis=0)
    
    Week4_Tot_App=df[df['week']=='week4']['Appliances'].sum()
    Week4_Mean_App=df[df['week']=='week4']['Appliances'].mean()
    Week4_Tot_light=df[df['week']=='week4']['lights'].sum()
    Week4_Mean_light=df[df['week']=='week4']['lights'].mean()
    Week4_Mean_T1=df[df['week']=='week4']['T1'].mean(axis=0)
    Week4_Mean_RH_1=df[df['week']=='week4']['RH_1'].mean(axis=0)
    Week4_Mean_T2=df[df['week']=='week4']['T2'].mean(axis=0)
    Week4_Mean_RH_2=df[df['week']=='week4']['RH_2'].mean(axis=0)
    Week4_Mean_T3=df[df['week']=='week4']['T3'].mean(axis=0)
    Week4_Mean_RH_3=df[df['week']=='week4']['RH_3'].mean(axis=0)
    Week4_Mean_T4=df[df['week']=='week4']['T4'].mean(axis=0)
    Week4_Mean_RH_4=df[df['week']=='week4']['RH_4'].mean(axis=0)
    Week4_Mean_T5=df[df['week']=='week4']['T5'].mean(axis=0)
    Week4_Mean_RH_5=df[df['week']=='week4']['RH_5'].mean(axis=0)
    Week4_Mean_T6=df[df['week']=='week4']['T6'].mean(axis=0)
    Week4_Mean_RH_6=df[df['week']=='week4']['RH_6'].mean(axis=0)
    Week4_Mean_T7=df[df['week']=='week4']['T7'].mean(axis=0)
    Week4_Mean_RH_7=df[df['week']=='week4']['RH_7'].mean(axis=0)
    Week4_Mean_T8=df[df['week']=='week4']['T8'].mean(axis=0)
    Week4_Mean_RH_8=df[df['week']=='week4']['RH_8'].mean(axis=0)
    Week4_Mean_T9=df[df['week']=='week4']['T9'].mean(axis=0)
    Week4_Mean_RH_9=df[df['week']=='week4']['RH_9'].mean(axis=0)
    Week4_Mean_T_out=df[df['week']=='week4']['T_out'].mean(axis=0)
    Week4_Mean_Press_mm_hg=df[df['week']=='week4']['Press_mm_hg'].mean(axis=0)
    Week4_Mean_RH_out=df[df['week']=='week4']['RH_out'].mean(axis=0)
    Week4_Mean_Windspeed=df[df['week']=='week4']['Windspeed'].mean(axis=0)
    Week4_Mean_Visibility=df[df['week']=='week4']['Visibility'].mean(axis=0)
    Week4_Mean_Tdewpoint=df[df['week']=='week4']['Tdewpoint'].mean(axis=0)
    
    Week5_Tot_App=df[df['week']=='week5']['Appliances'].sum()
    Week5_Mean_App=df[df['week']=='week5']['Appliances'].mean()
    Week5_Tot_light=df[df['week']=='week5']['lights'].sum()
    Week5_Mean_light=df[df['week']=='week5']['lights'].mean()
    Week5_Mean_T1=df[df['week']=='week5']['T1'].mean(axis=0)
    Week5_Mean_RH_1=df[df['week']=='week5']['RH_1'].mean(axis=0)
    Week5_Mean_T2=df[df['week']=='week5']['T2'].mean(axis=0)
    Week5_Mean_RH_2=df[df['week']=='week5']['RH_2'].mean(axis=0)
    Week5_Mean_T3=df[df['week']=='week5']['T3'].mean(axis=0)
    Week5_Mean_RH_3=df[df['week']=='week5']['RH_3'].mean(axis=0)
    Week5_Mean_T4=df[df['week']=='week5']['T4'].mean(axis=0)
    Week5_Mean_RH_4=df[df['week']=='week5']['RH_4'].mean(axis=0)
    Week5_Mean_T5=df[df['week']=='week5']['T5'].mean(axis=0)
    Week5_Mean_RH_5=df[df['week']=='week5']['RH_5'].mean(axis=0)
    Week5_Mean_T6=df[df['week']=='week5']['T6'].mean(axis=0)
    Week5_Mean_RH_6=df[df['week']=='week5']['RH_6'].mean(axis=0)
    Week5_Mean_T7=df[df['week']=='week5']['T7'].mean(axis=0)
    Week5_Mean_RH_7=df[df['week']=='week5']['RH_7'].mean(axis=0)
    Week5_Mean_T8=df[df['week']=='week5']['T8'].mean(axis=0)
    Week5_Mean_RH_8=df[df['week']=='week5']['RH_8'].mean(axis=0)
    Week5_Mean_T9=df[df['week']=='week5']['T9'].mean(axis=0)
    Week5_Mean_RH_9=df[df['week']=='week5']['RH_9'].mean(axis=0)
    Week5_Mean_T_out=df[df['week']=='week5']['T_out'].mean(axis=0)
    Week5_Mean_Press_mm_hg=df[df['week']=='week5']['Press_mm_hg'].mean(axis=0)
    Week5_Mean_RH_out=df[df['week']=='week5']['RH_out'].mean(axis=0)
    Week5_Mean_Windspeed=df[df['week']=='week5']['Windspeed'].mean(axis=0)
    Week5_Mean_Visibility=df[df['week']=='week5']['Visibility'].mean(axis=0)
    Week5_Mean_Tdewpoint=df[df['week']=='week5']['Tdewpoint'].mean(axis=0)
    
    Weekdays_Tot_App=df[df['week_day_type']=='weekdays']['Appliances'].sum()
    Weekdays_Mean_App=df[df['week_day_type']=='weekdays']['Appliances'].mean()
    Weekdays_Tot_light=df[df['week_day_type']=='weekdays']['lights'].sum()
    Weekdays_Mean_light=df[df['week_day_type']=='weekdays']['lights'].mean()
    Weekdays_Mean_T1=df[df['week_day_type']=='weekdays']['T1'].mean(axis=0)
    Weekdays_Mean_RH_1=df[df['week_day_type']=='weekdays']['RH_1'].mean(axis=0)
    Weekdays_Mean_T2=df[df['week_day_type']=='weekdays']['T2'].mean(axis=0)
    Weekdays_Mean_RH_2=df[df['week_day_type']=='weekdays']['RH_2'].mean(axis=0)
    Weekdays_Mean_T3=df[df['week_day_type']=='weekdays']['T3'].mean(axis=0)
    Weekdays_Mean_RH_3=df[df['week_day_type']=='weekdays']['RH_3'].mean(axis=0)
    Weekdays_Mean_T4=df[df['week_day_type']=='weekdays']['T4'].mean(axis=0)
    Weekdays_Mean_RH_4=df[df['week_day_type']=='weekdays']['RH_4'].mean(axis=0)
    Weekdays_Mean_T5=df[df['week_day_type']=='weekdays']['T5'].mean(axis=0)
    Weekdays_Mean_RH_5=df[df['week_day_type']=='weekdays']['RH_5'].mean(axis=0)
    Weekdays_Mean_T6=df[df['week_day_type']=='weekdays']['T6'].mean(axis=0)
    Weekdays_Mean_RH_6=df[df['week_day_type']=='weekdays']['RH_6'].mean(axis=0)
    Weekdays_Mean_T7=df[df['week_day_type']=='weekdays']['T7'].mean(axis=0)
    Weekdays_Mean_RH_7=df[df['week_day_type']=='weekdays']['RH_7'].mean(axis=0)
    Weekdays_Mean_T8=df[df['week_day_type']=='weekdays']['T8'].mean(axis=0)
    Weekdays_Mean_RH_8=df[df['week_day_type']=='weekdays']['RH_8'].mean(axis=0)
    Weekdays_Mean_T9=df[df['week_day_type']=='weekdays']['T9'].mean(axis=0)
    Weekdays_Mean_RH_9=df[df['week_day_type']=='weekdays']['RH_9'].mean(axis=0)
    Weekdays_Mean_T_out=df[df['week_day_type']=='weekdays']['T_out'].mean(axis=0)
    Weekdays_Mean_Press_mm_hg=df[df['week_day_type']=='weekdays']['Press_mm_hg'].mean(axis=0)
    Weekdays_Mean_RH_out=df[df['week_day_type']=='weekdays']['RH_out'].mean(axis=0)
    Weekdays_Mean_Windspeed=df[df['week_day_type']=='weekdays']['Windspeed'].mean(axis=0)
    Weekdays_Mean_Visibility=df[df['week_day_type']=='weekdays']['Visibility'].mean(axis=0)
    Weekdays_Mean_Tdewpoint=df[df['week_day_type']=='weekdays']['Tdewpoint'].mean(axis=0)
    
    Weekends_Tot_App=df[df['week_day_type']=='weekends']['Appliances'].sum()
    Weekends_Mean_App=df[df['week_day_type']=='weekends']['Appliances'].mean()
    Weekends_Tot_light=df[df['week_day_type']=='weekends']['lights'].sum()
    Weekends_Mean_light=df[df['week_day_type']=='weekends']['lights'].mean()
    Weekends_Mean_T1=df[df['week_day_type']=='weekends']['T1'].mean(axis=0)
    Weekends_Mean_RH_1=df[df['week_day_type']=='weekends']['RH_1'].mean(axis=0)
    Weekends_Mean_T2=df[df['week_day_type']=='weekends']['T2'].mean(axis=0)
    Weekends_Mean_RH_2=df[df['week_day_type']=='weekends']['RH_2'].mean(axis=0)
    Weekends_Mean_T3=df[df['week_day_type']=='weekends']['T3'].mean(axis=0)
    Weekends_Mean_RH_3=df[df['week_day_type']=='weekends']['RH_3'].mean(axis=0)
    Weekends_Mean_T4=df[df['week_day_type']=='weekends']['T4'].mean(axis=0)
    Weekends_Mean_RH_4=df[df['week_day_type']=='weekends']['RH_4'].mean(axis=0)
    Weekends_Mean_T5=df[df['week_day_type']=='weekends']['T5'].mean(axis=0)
    Weekends_Mean_RH_5=df[df['week_day_type']=='weekends']['RH_5'].mean(axis=0)
    Weekends_Mean_T6=df[df['week_day_type']=='weekends']['T6'].mean(axis=0)
    Weekends_Mean_RH_6=df[df['week_day_type']=='weekends']['RH_6'].mean(axis=0)
    Weekends_Mean_T7=df[df['week_day_type']=='weekends']['T7'].mean(axis=0)
    Weekends_Mean_RH_7=df[df['week_day_type']=='weekends']['RH_7'].mean(axis=0)
    Weekends_Mean_T8=df[df['week_day_type']=='weekends']['T8'].mean(axis=0)
    Weekends_Mean_RH_8=df[df['week_day_type']=='weekends']['RH_8'].mean(axis=0)
    Weekends_Mean_T9=df[df['week_day_type']=='weekends']['T9'].mean(axis=0)
    Weekends_Mean_RH_9=df[df['week_day_type']=='weekends']['RH_9'].mean(axis=0)
    Weekends_Mean_T_out=df[df['week_day_type']=='weekends']['T_out'].mean(axis=0)
    Weekends_Mean_Press_mm_hg=df[df['week_day_type']=='weekends']['Press_mm_hg'].mean(axis=0)
    Weekends_Mean_RH_out=df[df['week_day_type']=='weekends']['RH_out'].mean(axis=0)
    Weekends_Mean_Windspeed=df[df['week_day_type']=='weekends']['Windspeed'].mean(axis=0)
    Weekends_Mean_Visibility=df[df['week_day_type']=='weekends']['Visibility'].mean(axis=0)
    Weekends_Mean_Tdewpoint=df[df['week_day_type']=='weekends']['Tdewpoint'].mean(axis=0)
    
    data={'Month':moth,'Tot_Appliance':Tot_Appliance,'Avg_Appliance':Avg_Appliance,'Tot_light':Tot_light,'Avg_light':Avg_light,'Tot_Energy':Tot_Energy,'Avg_Energy':Avg_Energy,
          'Mean_T1':Mean_T1,'Mean_RH_1':Mean_RH_1,'Mean_T2':Mean_T2,'Mean_RH_2':Mean_RH_2,'Mean_T3':Mean_T3,'Mean_RH_3':Mean_RH_3,
          'Mean_T4':Mean_T4,'Mean_RH_4':Mean_RH_4,'Mean_T5':Mean_T5,'Mean_RH_5':Mean_RH_5,'Mean_T6':Mean_T6,'Mean_RH_6':Mean_RH_6,
          'Mean_T7':Mean_T7,'Mean_RH_7':Mean_RH_7,'Mean_T8':Mean_T8,'Mean_RH_8':Mean_RH_8,'Mean_T9':Mean_T9,'Mean_RH_9':Mean_RH_9,
          'Mean_T_out':Mean_T_out,'Mean_Press_mm_hg':Mean_Press_mm_hg,'Mean_RH_out':Mean_RH_out,'Mean_Windspeed':Mean_Windspeed,'Mean_Visibility':Mean_Visibility,
          'Mean_Tdewpoint':Mean_Tdewpoint,'Tot_Morning_App':Tot_Morning_App,'Mean_Morning_App':Mean_Morning_App,'Tot_Afternoon_App':Tot_Afternoon_App,
          'Mean_Afternoon_App':Mean_Afternoon_App,'Tot_Evening_App':Tot_Evening_App,'Mean_Evening_App':Mean_Evening_App,
          'Tot_Night_App':Tot_Night_App,'Mean_Night_App':Mean_Night_App,'Tot_Morning_light':Tot_Morning_light,'Mean_Morning_light':Mean_Morning_light,
          'Tot_Afternoon_light':Tot_Afternoon_light,'Mean_Afternoon_light':Mean_Afternoon_light,'Tot_Evening_light':Tot_Evening_light,
          'Mean_Evening_light':Mean_Evening_light,'Tot_Night_light':Tot_Night_light,'Mean_Night_light':Mean_Night_light,
          
          'Morn_Mean_T1':Morn_Mean_T1,'Morn_Mean_RH_1':Morn_Mean_RH_1,'Morn_Mean_T2':Morn_Mean_T2,'Morn_Mean_RH_2':Morn_Mean_RH_2,'Morn_Mean_T3':Morn_Mean_T3,'Morn_Mean_RH_3':Morn_Mean_RH_3,
          'Morn_Mean_T4':Morn_Mean_T4,'Morn_Mean_RH_4':Morn_Mean_RH_4,'Morn_Mean_T5':Morn_Mean_T5,'Morn_Mean_RH_5':Morn_Mean_RH_5,'Morn_Mean_T6':Morn_Mean_T6,'Morn_Mean_RH_6':Morn_Mean_RH_6,
          'Morn_Mean_T7':Morn_Mean_T7,'Morn_Mean_RH_7':Morn_Mean_RH_7,'Morn_Mean_T8':Morn_Mean_T8,'Morn_Mean_RH_8':Morn_Mean_RH_8,'Morn_Mean_T9':Morn_Mean_T9,'Morn_Mean_RH_9':Morn_Mean_RH_9,
          'Morn_Mean_T_out':Morn_Mean_T_out,'Morn_Mean_Press_mm_hg':Morn_Mean_Press_mm_hg,'Morn_Mean_RH_out':Morn_Mean_RH_out,'Morn_Mean_Windspeed':Morn_Mean_Windspeed,'Morn_Mean_Visibility':Morn_Mean_Visibility,
          'Morn_Mean_Tdewpoint':Morn_Mean_Tdewpoint,
          
          'After_Mean_T1':After_Mean_T1,'After_Mean_RH_1':After_Mean_RH_1,'After_Mean_T2':After_Mean_T2,'After_Mean_RH_2':After_Mean_RH_2,'After_Mean_T3':After_Mean_T3,'After_Mean_RH_3':After_Mean_RH_3,
          'After_Mean_T4':After_Mean_T4,'After_Mean_RH_4':After_Mean_RH_4,'After_Mean_T5':After_Mean_T5,'After_Mean_RH_5':After_Mean_RH_5,'After_Mean_T6':After_Mean_T6,'After_Mean_RH_6':After_Mean_RH_6,
          'After_Mean_T7':After_Mean_T7,'After_Mean_RH_7':After_Mean_RH_7,'After_Mean_T8':After_Mean_T8,'After_Mean_RH_8':After_Mean_RH_8,'After_Mean_T9':After_Mean_T9,'After_Mean_RH_9':After_Mean_RH_9,
          'After_Mean_T_out':After_Mean_T_out,'After_Mean_Press_mm_hg':After_Mean_Press_mm_hg,'After_Mean_RH_out':After_Mean_RH_out,'After_Mean_Windspeed':After_Mean_Windspeed,'After_Mean_Visibility':After_Mean_Visibility,
          'After_Mean_Tdewpoint':After_Mean_Tdewpoint,
          
          'Eve_Mean_T1':Eve_Mean_T1,'Eve_Mean_RH_1':Eve_Mean_RH_1,'Eve_Mean_T2':Eve_Mean_T2,'Eve_Mean_RH_2':Eve_Mean_RH_2,'Eve_Mean_T3':Eve_Mean_T3,'Eve_Mean_RH_3':Eve_Mean_RH_3,
          'Eve_Mean_T4':Eve_Mean_T4,'Eve_Mean_RH_4':Eve_Mean_RH_4,'Eve_Mean_T5':Eve_Mean_T5,'Eve_Mean_RH_5':Eve_Mean_RH_5,'Eve_Mean_T6':Eve_Mean_T6,'Eve_Mean_RH_6':Eve_Mean_RH_6,
          'Eve_Mean_T7':Eve_Mean_T7,'Eve_Mean_RH_7':Eve_Mean_RH_7,'Eve_Mean_T8':Eve_Mean_T8,'Eve_Mean_RH_8':Eve_Mean_RH_8,'Eve_Mean_T9':Eve_Mean_T9,'Eve_Mean_RH_9':Eve_Mean_RH_9,
          'Eve_Mean_T_out':Eve_Mean_T_out,'Eve_Mean_Press_mm_hg':Eve_Mean_Press_mm_hg,'Eve_Mean_RH_out':Eve_Mean_RH_out,'Eve_Mean_Windspeed':Eve_Mean_Windspeed,'Eve_Mean_Visibility':Eve_Mean_Visibility,
          'Eve_Mean_Tdewpoint':Eve_Mean_Tdewpoint,
          
          'Night_Mean_T1':Night_Mean_T1,'Night_Mean_RH_1':Night_Mean_RH_1,'Night_Mean_T2':Night_Mean_T2,'Night_Mean_RH_2':Night_Mean_RH_2,'Night_Mean_T3':Night_Mean_T3,'Night_Mean_RH_3':Night_Mean_RH_3,
          'Night_Mean_T4':Night_Mean_T4,'Night_Mean_RH_4':Night_Mean_RH_4,'Night_Mean_T5':Night_Mean_T5,'Night_Mean_RH_5':Night_Mean_RH_5,'Night_Mean_T6':Night_Mean_T6,'Night_Mean_RH_6':Night_Mean_RH_6,
          'Night_Mean_T7':Night_Mean_T7,'Night_Mean_RH_7':Night_Mean_RH_7,'Night_Mean_T8':Night_Mean_T8,'Night_Mean_RH_8':Night_Mean_RH_8,'Night_Mean_T9':Night_Mean_T9,'Night_Mean_RH_9':Night_Mean_RH_9,
          'Night_Mean_T_out':Night_Mean_T_out,'Night_Mean_Press_mm_hg':Night_Mean_Press_mm_hg,'Night_Mean_RH_out':Night_Mean_RH_out,'Night_Mean_Windspeed':Night_Mean_Windspeed,'Night_Mean_Visibility':Night_Mean_Visibility,
          'Night_Mean_Tdewpoint':Night_Mean_Tdewpoint,
         
          'Week1_Tot_App':Week1_Tot_App,'Week1_Mean_App':Week1_Mean_App,'Week1_Tot_light':Week1_Tot_light,'Week1_Mean_light':Week1_Mean_light,
          'Week1_Mean_T1':Week1_Mean_T1,'Week1_Mean_RH_1':Week1_Mean_RH_1,'Week1_Mean_T2':Week1_Mean_T2,'Week1_Mean_RH_2':Week1_Mean_RH_2,'Week1_Mean_T3':Week1_Mean_T3,'Week1_Mean_RH_3':Week1_Mean_RH_3,
          'Week1_Mean_T4':Week1_Mean_T4,'Week1_Mean_RH_4':Week1_Mean_RH_4,'Week1_Mean_T5':Week1_Mean_T5,'Week1_Mean_RH_5':Week1_Mean_RH_5,'Week1_Mean_T6':Week1_Mean_T6,'Week1_Mean_RH_6':Week1_Mean_RH_6,
          'Week1_Mean_T7':Week1_Mean_T7,'Week1_Mean_RH_7':Week1_Mean_RH_7,'Week1_Mean_T8':Week1_Mean_T8,'Week1_Mean_RH_8':Week1_Mean_RH_8,'Week1_Mean_T9':Week1_Mean_T9,'Week1_Mean_RH_9':Week1_Mean_RH_9,
          'Week1_Mean_T_out':Week1_Mean_T_out,'Week1_Mean_Press_mm_hg':Week1_Mean_Press_mm_hg,'Week1_Mean_RH_out':Week1_Mean_RH_out,'Week1_Mean_Windspeed':Week1_Mean_Windspeed,'Week1_Mean_Visibility':Week1_Mean_Visibility,
          'Week1_Mean_Tdewpoint':Week1_Mean_Tdewpoint,
           
          'Week2_Tot_App':Week2_Tot_App,'Week2_Mean_App':Week2_Mean_App,'Week2_Tot_light':Week2_Tot_light,'Week2_Mean_light':Week2_Mean_light,
          'Week2_Mean_T1':Week2_Mean_T1,'Week2_Mean_RH_1':Week2_Mean_RH_1,'Week2_Mean_T2':Week2_Mean_T2,'Week2_Mean_RH_2':Week2_Mean_RH_2,'Week2_Mean_T3':Week2_Mean_T3,'Week2_Mean_RH_3':Week2_Mean_RH_3,
          'Week2_Mean_T4':Week2_Mean_T4,'Week2_Mean_RH_4':Week2_Mean_RH_4,'Week2_Mean_T5':Week2_Mean_T5,'Week2_Mean_RH_5':Week2_Mean_RH_5,'Week2_Mean_T6':Week2_Mean_T6,'Week2_Mean_RH_6':Week2_Mean_RH_6,
          'Week2_Mean_T7':Week2_Mean_T7,'Week2_Mean_RH_7':Week2_Mean_RH_7,'Week2_Mean_T8':Week2_Mean_T8,'Week2_Mean_RH_8':Week2_Mean_RH_8,'Week2_Mean_T9':Week2_Mean_T9,'Week2_Mean_RH_9':Week2_Mean_RH_9,
          'Week2_Mean_T_out':Week2_Mean_T_out,'Week2_Mean_Press_mm_hg':Week2_Mean_Press_mm_hg,'Week2_Mean_RH_out':Week2_Mean_RH_out,'Week2_Mean_Windspeed':Week2_Mean_Windspeed,'Week2_Mean_Visibility':Week2_Mean_Visibility,
          'Week2_Mean_Tdewpoint':Week2_Mean_Tdewpoint,
         
          'Week3_Tot_App':Week3_Tot_App,'Week3_Mean_App':Week3_Mean_App,'Week3_Tot_light':Week3_Tot_light,'Week3_Mean_light':Week3_Mean_light,
          'Week3_Mean_T1':Week3_Mean_T1,'Week3_Mean_RH_1':Week3_Mean_RH_1,'Week3_Mean_T2':Week3_Mean_T2,'Week3_Mean_RH_2':Week3_Mean_RH_2,'Week3_Mean_T3':Week3_Mean_T3,'Week3_Mean_RH_3':Week3_Mean_RH_3,
          'Week3_Mean_T4':Week3_Mean_T4,'Week3_Mean_RH_4':Week3_Mean_RH_4,'Week3_Mean_T5':Week3_Mean_T5,'Week3_Mean_RH_5':Week3_Mean_RH_5,'Week3_Mean_T6':Week3_Mean_T6,'Week3_Mean_RH_6':Week3_Mean_RH_6,
          'Week3_Mean_T7':Week3_Mean_T7,'Week3_Mean_RH_7':Week3_Mean_RH_7,'Week3_Mean_T8':Week3_Mean_T8,'Week3_Mean_RH_8':Week3_Mean_RH_8,'Week3_Mean_T9':Week3_Mean_T9,'Week3_Mean_RH_9':Week3_Mean_RH_9,
          'Week3_Mean_T_out':Week3_Mean_T_out,'Week3_Mean_Press_mm_hg':Week3_Mean_Press_mm_hg,'Week3_Mean_RH_out':Week3_Mean_RH_out,'Week3_Mean_Windspeed':Week3_Mean_Windspeed,'Week3_Mean_Visibility':Week3_Mean_Visibility,
          'Week3_Mean_Tdewpoint':Week3_Mean_Tdewpoint,
         
          'Week4_Tot_App':Week4_Tot_App,'Week4_Mean_App':Week4_Mean_App,'Week4_Tot_light':Week4_Tot_light,'Week4_Mean_light':Week4_Mean_light,
          'Week4_Mean_T1':Week4_Mean_T1,'Week4_Mean_RH_1':Week4_Mean_RH_1,'Week4_Mean_T2':Week4_Mean_T2,'Week4_Mean_RH_2':Week4_Mean_RH_2,'Week4_Mean_T3':Week4_Mean_T3,'Week4_Mean_RH_3':Week4_Mean_RH_3,
          'Week4_Mean_T4':Week4_Mean_T4,'Week4_Mean_RH_4':Week4_Mean_RH_4,'Week4_Mean_T5':Week4_Mean_T5,'Week4_Mean_RH_5':Week4_Mean_RH_5,'Week4_Mean_T6':Week4_Mean_T6,'Week4_Mean_RH_6':Week4_Mean_RH_6,
          'Week4_Mean_T7':Week4_Mean_T7,'Week4_Mean_RH_7':Week4_Mean_RH_7,'Week4_Mean_T8':Week4_Mean_T8,'Week4_Mean_RH_8':Week4_Mean_RH_8,'Week4_Mean_T9':Week4_Mean_T9,'Week4_Mean_RH_9':Week4_Mean_RH_9,
          'Week4_Mean_T_out':Week4_Mean_T_out,'Week4_Mean_Press_mm_hg':Week4_Mean_Press_mm_hg,'Week4_Mean_RH_out':Week4_Mean_RH_out,'Week4_Mean_Windspeed':Week4_Mean_Windspeed,'Week4_Mean_Visibility':Week4_Mean_Visibility,
          'Week4_Mean_Tdewpoint':Week4_Mean_Tdewpoint,
          
          'Week5_Tot_App':Week5_Tot_App,'Week5_Mean_App':Week5_Mean_App,'Week5_Tot_light':Week5_Tot_light,'Week5_Mean_light':Week5_Mean_light,
          'Week5_Mean_T1':Week5_Mean_T1,'Week5_Mean_RH_1':Week5_Mean_RH_1,'Week5_Mean_T2':Week5_Mean_T2,'Week5_Mean_RH_2':Week5_Mean_RH_2,'Week5_Mean_T3':Week5_Mean_T3,'Week5_Mean_RH_3':Week5_Mean_RH_3,
          'Week5_Mean_T4':Week5_Mean_T4,'Week5_Mean_RH_4':Week5_Mean_RH_4,'Week5_Mean_T5':Week5_Mean_T5,'Week5_Mean_RH_5':Week5_Mean_RH_5,'Week5_Mean_T6':Week5_Mean_T6,'Week5_Mean_RH_6':Week5_Mean_RH_6,
          'Week5_Mean_T7':Week5_Mean_T7,'Week5_Mean_RH_7':Week5_Mean_RH_7,'Week5_Mean_T8':Week5_Mean_T8,'Week5_Mean_RH_8':Week5_Mean_RH_8,'Week5_Mean_T9':Week5_Mean_T9,'Week5_Mean_RH_9':Week5_Mean_RH_9,
          'Week5_Mean_T_out':Week5_Mean_T_out,'Week5_Mean_Press_mm_hg':Week5_Mean_Press_mm_hg,'Week5_Mean_RH_out':Week5_Mean_RH_out,'Week5_Mean_Windspeed':Week5_Mean_Windspeed,'Week5_Mean_Visibility':Week5_Mean_Visibility,
          'Week5_Mean_Tdewpoint':Week5_Mean_Tdewpoint,
         
          'Weekdays_Tot_App':Weekdays_Tot_App,'Weekdays_Mean_App':Weekdays_Mean_App,'Weekdays_Tot_light':Weekdays_Tot_light,'Weekdays_Mean_light':Weekdays_Mean_light,
          'Weekdays_Mean_T1':Weekdays_Mean_T1,'Weekdays_Mean_RH_1':Weekdays_Mean_RH_1,'Weekdays_Mean_T2':Weekdays_Mean_T2,'Weekdays_Mean_RH_2':Weekdays_Mean_RH_2,'Weekdays_Mean_T3':Weekdays_Mean_T3,'Weekdays_Mean_RH_3':Weekdays_Mean_RH_3,
          'Weekdays_Mean_T4':Weekdays_Mean_T4,'Weekdays_Mean_RH_4':Weekdays_Mean_RH_4,'Weekdays_Mean_T5':Weekdays_Mean_T5,'Weekdays_Mean_RH_5':Weekdays_Mean_RH_5,'Weekdays_Mean_T6':Weekdays_Mean_T6,'Weekdays_Mean_RH_6':Weekdays_Mean_RH_6,
          'Weekdays_Mean_T7':Weekdays_Mean_T7,'Weekdays_Mean_RH_7':Weekdays_Mean_RH_7,'Weekdays_Mean_T8':Weekdays_Mean_T8,'Weekdays_Mean_RH_8':Weekdays_Mean_RH_8,'Weekdays_Mean_T9':Weekdays_Mean_T9,'Weekdays_Mean_RH_9':Weekdays_Mean_RH_9,
          'Weekdays_Mean_T_out':Weekdays_Mean_T_out,'Weekdays_Mean_Press_mm_hg':Weekdays_Mean_Press_mm_hg,'Weekdays_Mean_RH_out':Weekdays_Mean_RH_out,'Weekdays_Mean_Windspeed':Weekdays_Mean_Windspeed,'Weekdays_Mean_Visibility':Weekdays_Mean_Visibility,
          'Weekdays_Mean_Tdewpoint':Weekdays_Mean_Tdewpoint,
         
          'Weekends_Tot_App':Weekends_Tot_App,'Weekends_Mean_App':Weekends_Mean_App,'Weekends_Tot_light':Weekends_Tot_light,'Weekends_Mean_light':Weekends_Mean_light,
          'Weekends_Mean_T1':Weekends_Mean_T1,'Weekends_Mean_RH_1':Weekends_Mean_RH_1,'Weekends_Mean_T2':Weekends_Mean_T2,'Weekends_Mean_RH_2':Weekends_Mean_RH_2,'Weekends_Mean_T3':Weekends_Mean_T3,'Weekends_Mean_RH_3':Weekends_Mean_RH_3,
          'Weekends_Mean_T4':Weekends_Mean_T4,'Weekends_Mean_RH_4':Weekends_Mean_RH_4,'Weekends_Mean_T5':Weekends_Mean_T5,'Weekends_Mean_RH_5':Weekends_Mean_RH_5,'Weekends_Mean_T6':Weekends_Mean_T6,'Weekends_Mean_RH_6':Weekends_Mean_RH_6,
          'Weekends_Mean_T7':Weekends_Mean_T7,'Weekends_Mean_RH_7':Weekends_Mean_RH_7,'Weekends_Mean_T8':Weekends_Mean_T8,'Weekends_Mean_RH_8':Weekends_Mean_RH_8,'Weekends_Mean_T9':Weekends_Mean_T9,'Weekends_Mean_RH_9':Weekends_Mean_RH_9,
          'Weekends_Mean_T_out':Weekends_Mean_T_out,'Weekends_Mean_Press_mm_hg':Weekends_Mean_Press_mm_hg,'Weekends_Mean_RH_out':Weekends_Mean_RH_out,'Weekends_Mean_Windspeed':Weekends_Mean_Windspeed,'Weekends_Mean_Visibility':Weekends_Mean_Visibility,
          'Weekends_Mean_Tdewpoint':Weekends_Mean_Tdewpoint}
    
    df_summ=df_summ.append(data,ignore_index=True)
    
    
    moth=moth=calendar.month_abbr[key]
    Max_App=df['Appliances'].max()
    Max_light=df['lights'].max()
    Max_T1=df['T1'].max()
    Max_RH_1=df['RH_1'].max()
    Max_T2=df['T2'].max()
    Max_RH_2=df['RH_2'].max()
    Max_T3=df['T3'].max()
    Max_RH_3=df['RH_3'].max()
    Max_T4=df['T4'].max()
    Max_RH_4=df['RH_4'].max()
    Max_T5=df['T5'].max()
    Max_RH_5=df['RH_5'].max()
    Max_T6=df['T6'].max()
    Max_RH_6=df['RH_6'].max()
    Max_T7=df['T7'].max()
    Max_RH_7=df['RH_7'].max()
    Max_T8=df['T8'].max()
    Max_RH_8=df['RH_8'].max()
    Max_T9=df['T9'].max()
    Max_RH_9=df['RH_9'].max()
    Max_T_out=df['T_out'].max()
    Max_Press_mm_hg=df['Press_mm_hg'].max()
    Max_RH_out=df['RH_out'].max()
    Max_Windspeed=df['Windspeed'].max()
    Max_Visibility=df['Visibility'].max()
    Max_Tdewpoint=df['Tdewpoint'].max()
    Min_App=df['Appliances'].min()
    Min_light=df['lights'].min()
    Min_T1=df['T1'].min()
    Min_RH_1=df['RH_1'].min()
    Min_T2=df['T2'].min()
    Min_RH_2=df['RH_2'].min()
    Min_T3=df['T3'].min()
    Min_RH_3=df['RH_3'].min()
    Min_T4=df['T4'].min()
    Min_RH_4=df['RH_4'].min()
    Min_T5=df['T5'].min()
    Min_RH_5=df['RH_5'].min()
    Min_T6=df['T6'].min()
    Min_RH_6=df['RH_6'].min()
    Min_T7=df['T7'].min()
    Min_RH_7=df['RH_7'].min()
    Min_T8=df['T8'].min()
    Min_RH_8=df['RH_8'].min()
    Min_T9=df['T9'].min()
    Min_RH_9=df['RH_9'].min()
    Min_T_out=df['T_out'].min()
    Min_Press_mm_hg=df['Press_mm_hg'].min()
    Min_RH_out=df['RH_out'].min()
    Min_Windspeed=df['Windspeed'].min()
    Min_Visibility=df['Visibility'].min()
    Min_Tdewpoint=df['Tdewpoint'].min()
    
    Week1_Max_App=df[df['week']=='week1']['Appliances'].max()
    Week1_Max_light=df[df['week']=='week1']['lights'].max()
    Week1_Max_T1=df[df['week']=='week1']['T1'].max()
    Week1_Max_RH_1=df[df['week']=='week1']['RH_1'].max()
    Week1_Max_T2=df[df['week']=='week1']['T2'].max()
    Week1_Max_RH_2=df[df['week']=='week1']['RH_2'].max()
    Week1_Max_T3=df[df['week']=='week1']['T3'].max()
    Week1_Max_RH_3=df[df['week']=='week1']['RH_3'].max()
    Week1_Max_T4=df[df['week']=='week1']['T4'].max()
    Week1_Max_RH_4=df[df['week']=='week1']['RH_4'].max()
    Week1_Max_T5=df[df['week']=='week1']['T5'].max()
    Week1_Max_RH_5=df[df['week']=='week1']['RH_5'].max()
    Week1_Max_T6=df[df['week']=='week1']['T6'].max()
    Week1_Max_RH_6=df[df['week']=='week1']['RH_6'].max()
    Week1_Max_T7=df[df['week']=='week1']['T7'].max()
    Week1_Max_RH_7=df[df['week']=='week1']['RH_7'].max()
    Week1_Max_T8=df[df['week']=='week1']['T8'].max()
    Week1_Max_RH_8=df[df['week']=='week1']['RH_8'].max()
    Week1_Max_T9=df[df['week']=='week1']['T9'].max()
    Week1_Max_RH_9=df[df['week']=='week1']['RH_9'].max()
    Week1_Max_T_out=df[df['week']=='week1']['T_out'].max()
    Week1_Max_Press_mm_hg=df[df['week']=='week1']['Press_mm_hg'].max()
    Week1_Max_RH_out=df[df['week']=='week1']['RH_out'].max()
    Week1_Max_Windspeed=df[df['week']=='week1']['Windspeed'].max()
    Week1_Max_Visibility=df[df['week']=='week1']['Visibility'].max()
    Week1_Max_Tdewpoint=df[df['week']=='week1']['Tdewpoint'].max()
    Week1_Min_App=df[df['week']=='week1']['Appliances'].min()
    Week1_Min_light=df[df['week']=='week1']['lights'].min()
    Week1_Min_T1=df[df['week']=='week1']['T1'].min()
    Week1_Min_RH_1=df[df['week']=='week1']['RH_1'].min()
    Week1_Min_T2=df[df['week']=='week1']['T2'].min()
    Week1_Min_RH_2=df[df['week']=='week1']['RH_2'].min()
    Week1_Min_T3=df[df['week']=='week1']['T3'].min()
    Week1_Min_RH_3=df[df['week']=='week1']['RH_3'].min()
    Week1_Min_T4=df[df['week']=='week1']['T4'].min()
    Week1_Min_RH_4=df[df['week']=='week1']['RH_4'].min()
    Week1_Min_T5=df[df['week']=='week1']['T5'].min()
    Week1_Min_RH_5=df[df['week']=='week1']['RH_5'].min()
    Week1_Min_T6=df[df['week']=='week1']['T6'].min()
    Week1_Min_RH_6=df[df['week']=='week1']['RH_6'].min()
    Week1_Min_T7=df[df['week']=='week1']['T7'].min()
    Week1_Min_RH_7=df[df['week']=='week1']['RH_7'].min()
    Week1_Min_T8=df[df['week']=='week1']['T8'].min()
    Week1_Min_RH_8=df[df['week']=='week1']['RH_8'].min()
    Week1_Min_T9=df[df['week']=='week1']['T9'].min()
    Week1_Min_RH_9=df[df['week']=='week1']['RH_9'].min()
    Week1_Min_T_out=df[df['week']=='week1']['T_out'].min()
    Week1_Min_Press_mm_hg=df[df['week']=='week1']['Press_mm_hg'].min()
    Week1_Min_RH_out=df[df['week']=='week1']['RH_out'].min()
    Week1_Min_Windspeed=df[df['week']=='week1']['Windspeed'].min()
    Week1_Min_Visibility=df[df['week']=='week1']['Visibility'].min()
    Week1_Min_Tdewpoint=df[df['week']=='week1']['Tdewpoint'].min()
    
    Week2_Max_App=df[df['week']=='week2']['Appliances'].max()
    Week2_Max_light=df[df['week']=='week2']['lights'].max()
    Week2_Max_T1=df[df['week']=='week2']['T1'].max()
    Week2_Max_RH_1=df[df['week']=='week2']['RH_1'].max()
    Week2_Max_T2=df[df['week']=='week2']['T2'].max()
    Week2_Max_RH_2=df[df['week']=='week2']['RH_2'].max()
    Week2_Max_T3=df[df['week']=='week2']['T3'].max()
    Week2_Max_RH_3=df[df['week']=='week2']['RH_3'].max()
    Week2_Max_T4=df[df['week']=='week2']['T4'].max()
    Week2_Max_RH_4=df[df['week']=='week2']['RH_4'].max()
    Week2_Max_T5=df[df['week']=='week2']['T5'].max()
    Week2_Max_RH_5=df[df['week']=='week2']['RH_5'].max()
    Week2_Max_T6=df[df['week']=='week2']['T6'].max()
    Week2_Max_RH_6=df[df['week']=='week2']['RH_6'].max()
    Week2_Max_T7=df[df['week']=='week2']['T7'].max()
    Week2_Max_RH_7=df[df['week']=='week2']['RH_7'].max()
    Week2_Max_T8=df[df['week']=='week2']['T8'].max()
    Week2_Max_RH_8=df[df['week']=='week2']['RH_8'].max()
    Week2_Max_T9=df[df['week']=='week2']['T9'].max()
    Week2_Max_RH_9=df[df['week']=='week2']['RH_9'].max()
    Week2_Max_T_out=df[df['week']=='week2']['T_out'].max()
    Week2_Max_Press_mm_hg=df[df['week']=='week2']['Press_mm_hg'].max()
    Week2_Max_RH_out=df[df['week']=='week2']['RH_out'].max()
    Week2_Max_Windspeed=df[df['week']=='week2']['Windspeed'].max()
    Week2_Max_Visibility=df[df['week']=='week2']['Visibility'].max()
    Week2_Max_Tdewpoint=df[df['week']=='week2']['Tdewpoint'].max()
    Week2_Min_App=df[df['week']=='week2']['Appliances'].min()
    Week2_Min_light=df[df['week']=='week2']['lights'].min()
    Week2_Min_T1=df[df['week']=='week2']['T1'].min()
    Week2_Min_RH_1=df[df['week']=='week2']['RH_1'].min()
    Week2_Min_T2=df[df['week']=='week2']['T2'].min()
    Week2_Min_RH_2=df[df['week']=='week2']['RH_2'].min()
    Week2_Min_T3=df[df['week']=='week2']['T3'].min()
    Week2_Min_RH_3=df[df['week']=='week2']['RH_3'].min()
    Week2_Min_T4=df[df['week']=='week2']['T4'].min()
    Week2_Min_RH_4=df[df['week']=='week2']['RH_4'].min()
    Week2_Min_T5=df[df['week']=='week2']['T5'].min()
    Week2_Min_RH_5=df[df['week']=='week2']['RH_5'].min()
    Week2_Min_T6=df[df['week']=='week2']['T6'].min()
    Week2_Min_RH_6=df[df['week']=='week2']['RH_6'].min()
    Week2_Min_T7=df[df['week']=='week2']['T7'].min()
    Week2_Min_RH_7=df[df['week']=='week2']['RH_7'].min()
    Week2_Min_T8=df[df['week']=='week2']['T8'].min()
    Week2_Min_RH_8=df[df['week']=='week2']['RH_8'].min()
    Week2_Min_T9=df[df['week']=='week2']['T9'].min()
    Week2_Min_RH_9=df[df['week']=='week2']['RH_9'].min()
    Week2_Min_T_out=df[df['week']=='week2']['T_out'].min()
    Week2_Min_Press_mm_hg=df[df['week']=='week2']['Press_mm_hg'].min()
    Week2_Min_RH_out=df[df['week']=='week2']['RH_out'].min()
    Week2_Min_Windspeed=df[df['week']=='week2']['Windspeed'].min()
    Week2_Min_Visibility=df[df['week']=='week2']['Visibility'].min()
    Week2_Min_Tdewpoint=df[df['week']=='week2']['Tdewpoint'].min()
    
    Week3_Max_App=df[df['week']=='week3']['Appliances'].max()
    Week3_Max_light=df[df['week']=='week3']['lights'].max()
    Week3_Max_T1=df[df['week']=='week3']['T1'].max()
    Week3_Max_RH_1=df[df['week']=='week3']['RH_1'].max()
    Week3_Max_T2=df[df['week']=='week3']['T2'].max()
    Week3_Max_RH_2=df[df['week']=='week3']['RH_2'].max()
    Week3_Max_T3=df[df['week']=='week3']['T3'].max()
    Week3_Max_RH_3=df[df['week']=='week3']['RH_3'].max()
    Week3_Max_T4=df[df['week']=='week3']['T4'].max()
    Week3_Max_RH_4=df[df['week']=='week3']['RH_4'].max()
    Week3_Max_T5=df[df['week']=='week3']['T5'].max()
    Week3_Max_RH_5=df[df['week']=='week3']['RH_5'].max()
    Week3_Max_T6=df[df['week']=='week3']['T6'].max()
    Week3_Max_RH_6=df[df['week']=='week3']['RH_6'].max()
    Week3_Max_T7=df[df['week']=='week3']['T7'].max()
    Week3_Max_RH_7=df[df['week']=='week3']['RH_7'].max()
    Week3_Max_T8=df[df['week']=='week3']['T8'].max()
    Week3_Max_RH_8=df[df['week']=='week3']['RH_8'].max()
    Week3_Max_T9=df[df['week']=='week3']['T9'].max()
    Week3_Max_RH_9=df[df['week']=='week3']['RH_9'].max()
    Week3_Max_T_out=df[df['week']=='week3']['T_out'].max()
    Week3_Max_Press_mm_hg=df[df['week']=='week3']['Press_mm_hg'].max()
    Week3_Max_RH_out=df[df['week']=='week3']['RH_out'].max()
    Week3_Max_Windspeed=df[df['week']=='week3']['Windspeed'].max()
    Week3_Max_Visibility=df[df['week']=='week3']['Visibility'].max()
    Week3_Max_Tdewpoint=df[df['week']=='week3']['Tdewpoint'].max()
    Week3_Min_App=df[df['week']=='week3']['Appliances'].min()
    Week3_Min_light=df[df['week']=='week3']['lights'].min()
    Week3_Min_T1=df[df['week']=='week3']['T1'].min()
    Week3_Min_RH_1=df[df['week']=='week3']['RH_1'].min()
    Week3_Min_T2=df[df['week']=='week3']['T2'].min()
    Week3_Min_RH_2=df[df['week']=='week3']['RH_2'].min()
    Week3_Min_T3=df[df['week']=='week3']['T3'].min()
    Week3_Min_RH_3=df[df['week']=='week3']['RH_3'].min()
    Week3_Min_T4=df[df['week']=='week3']['T4'].min()
    Week3_Min_RH_4=df[df['week']=='week3']['RH_4'].min()
    Week3_Min_T5=df[df['week']=='week3']['T5'].min()
    Week3_Min_RH_5=df[df['week']=='week3']['RH_5'].min()
    Week3_Min_T6=df[df['week']=='week3']['T6'].min()
    Week3_Min_RH_6=df[df['week']=='week3']['RH_6'].min()
    Week3_Min_T7=df[df['week']=='week3']['T7'].min()
    Week3_Min_RH_7=df[df['week']=='week3']['RH_7'].min()
    Week3_Min_T8=df[df['week']=='week3']['T8'].min()
    Week3_Min_RH_8=df[df['week']=='week3']['RH_8'].min()
    Week3_Min_T9=df[df['week']=='week3']['T9'].min()
    Week3_Min_RH_9=df[df['week']=='week3']['RH_9'].min()
    Week3_Min_T_out=df[df['week']=='week3']['T_out'].min()
    Week3_Min_Press_mm_hg=df[df['week']=='week3']['Press_mm_hg'].min()
    Week3_Min_RH_out=df[df['week']=='week3']['RH_out'].min()
    Week3_Min_Windspeed=df[df['week']=='week3']['Windspeed'].min()
    Week3_Min_Visibility=df[df['week']=='week3']['Visibility'].min()
    Week3_Min_Tdewpoint=df[df['week']=='week3']['Tdewpoint'].min()
    
    Week4_Max_App=df[df['week']=='week4']['Appliances'].max()
    Week4_Max_light=df[df['week']=='week4']['lights'].max()
    Week4_Max_T1=df[df['week']=='week4']['T1'].max()
    Week4_Max_RH_1=df[df['week']=='week4']['RH_1'].max()
    Week4_Max_T2=df[df['week']=='week4']['T2'].max()
    Week4_Max_RH_2=df[df['week']=='week4']['RH_2'].max()
    Week4_Max_T3=df[df['week']=='week4']['T3'].max()
    Week4_Max_RH_3=df[df['week']=='week4']['RH_3'].max()
    Week4_Max_T4=df[df['week']=='week4']['T4'].max()
    Week4_Max_RH_4=df[df['week']=='week4']['RH_4'].max()
    Week4_Max_T5=df[df['week']=='week4']['T5'].max()
    Week4_Max_RH_5=df[df['week']=='week4']['RH_5'].max()
    Week4_Max_T6=df[df['week']=='week4']['T6'].max()
    Week4_Max_RH_6=df[df['week']=='week4']['RH_6'].max()
    Week4_Max_T7=df[df['week']=='week4']['T7'].max()
    Week4_Max_RH_7=df[df['week']=='week4']['RH_7'].max()
    Week4_Max_T8=df[df['week']=='week4']['T8'].max()
    Week4_Max_RH_8=df[df['week']=='week4']['RH_8'].max()
    Week4_Max_T9=df[df['week']=='week4']['T9'].max()
    Week4_Max_RH_9=df[df['week']=='week4']['RH_9'].max()
    Week4_Max_T_out=df[df['week']=='week4']['T_out'].max()
    Week4_Max_Press_mm_hg=df[df['week']=='week4']['Press_mm_hg'].max()
    Week4_Max_RH_out=df[df['week']=='week4']['RH_out'].max()
    Week4_Max_Windspeed=df[df['week']=='week4']['Windspeed'].max()
    Week4_Max_Visibility=df[df['week']=='week4']['Visibility'].max()
    Week4_Max_Tdewpoint=df[df['week']=='week4']['Tdewpoint'].max()
    Week4_Min_App=df[df['week']=='week4']['Appliances'].min()
    Week4_Min_light=df[df['week']=='week4']['lights'].min()
    Week4_Min_T1=df[df['week']=='week4']['T1'].min()
    Week4_Min_RH_1=df[df['week']=='week4']['RH_1'].min()
    Week4_Min_T2=df[df['week']=='week4']['T2'].min()
    Week4_Min_RH_2=df[df['week']=='week4']['RH_2'].min()
    Week4_Min_T3=df[df['week']=='week4']['T3'].min()
    Week4_Min_RH_3=df[df['week']=='week4']['RH_3'].min()
    Week4_Min_T4=df[df['week']=='week4']['T4'].min()
    Week4_Min_RH_4=df[df['week']=='week4']['RH_4'].min()
    Week4_Min_T5=df[df['week']=='week4']['T5'].min()
    Week4_Min_RH_5=df[df['week']=='week4']['RH_5'].min()
    Week4_Min_T6=df[df['week']=='week4']['T6'].min()
    Week4_Min_RH_6=df[df['week']=='week4']['RH_6'].min()
    Week4_Min_T7=df[df['week']=='week4']['T7'].min()
    Week4_Min_RH_7=df[df['week']=='week4']['RH_7'].min()
    Week4_Min_T8=df[df['week']=='week4']['T8'].min()
    Week4_Min_RH_8=df[df['week']=='week4']['RH_8'].min()
    Week4_Min_T9=df[df['week']=='week4']['T9'].min()
    Week4_Min_RH_9=df[df['week']=='week4']['RH_9'].min()
    Week4_Min_T_out=df[df['week']=='week4']['T_out'].min()
    Week4_Min_Press_mm_hg=df[df['week']=='week4']['Press_mm_hg'].min()
    Week4_Min_RH_out=df[df['week']=='week4']['RH_out'].min()
    Week4_Min_Windspeed=df[df['week']=='week4']['Windspeed'].min()
    Week4_Min_Visibility=df[df['week']=='week4']['Visibility'].min()
    Week4_Min_Tdewpoint=df[df['week']=='week4']['Tdewpoint'].min()
    
    Week5_Max_App=df[df['week']=='week5']['Appliances'].max()
    Week5_Max_light=df[df['week']=='week5']['lights'].max()
    Week5_Max_T1=df[df['week']=='week5']['T1'].max()
    Week5_Max_RH_1=df[df['week']=='week5']['RH_1'].max()
    Week5_Max_T2=df[df['week']=='week5']['T2'].max()
    Week5_Max_RH_2=df[df['week']=='week5']['RH_2'].max()
    Week5_Max_T3=df[df['week']=='week5']['T3'].max()
    Week5_Max_RH_3=df[df['week']=='week5']['RH_3'].max()
    Week5_Max_T4=df[df['week']=='week5']['T4'].max()
    Week5_Max_RH_4=df[df['week']=='week5']['RH_4'].max()
    Week5_Max_T5=df[df['week']=='week5']['T5'].max()
    Week5_Max_RH_5=df[df['week']=='week5']['RH_5'].max()
    Week5_Max_T6=df[df['week']=='week5']['T6'].max()
    Week5_Max_RH_6=df[df['week']=='week5']['RH_6'].max()
    Week5_Max_T7=df[df['week']=='week5']['T7'].max()
    Week5_Max_RH_7=df[df['week']=='week5']['RH_7'].max()
    Week5_Max_T8=df[df['week']=='week5']['T8'].max()
    Week5_Max_RH_8=df[df['week']=='week5']['RH_8'].max()
    Week5_Max_T9=df[df['week']=='week5']['T9'].max()
    Week5_Max_RH_9=df[df['week']=='week5']['RH_9'].max()
    Week5_Max_T_out=df[df['week']=='week5']['T_out'].max()
    Week5_Max_Press_mm_hg=df[df['week']=='week5']['Press_mm_hg'].max()
    Week5_Max_RH_out=df[df['week']=='week5']['RH_out'].max()
    Week5_Max_Windspeed=df[df['week']=='week5']['Windspeed'].max()
    Week5_Max_Visibility=df[df['week']=='week5']['Visibility'].max()
    Week5_Max_Tdewpoint=df[df['week']=='week5']['Tdewpoint'].max()
    Week5_Min_App=df[df['week']=='week5']['Appliances'].min()
    Week5_Min_light=df[df['week']=='week5']['lights'].min()
    Week5_Min_T1=df[df['week']=='week5']['T1'].min()
    Week5_Min_RH_1=df[df['week']=='week5']['RH_1'].min()
    Week5_Min_T2=df[df['week']=='week5']['T2'].min()
    Week5_Min_RH_2=df[df['week']=='week5']['RH_2'].min()
    Week5_Min_T3=df[df['week']=='week5']['T3'].min()
    Week5_Min_RH_3=df[df['week']=='week5']['RH_3'].min()
    Week5_Min_T4=df[df['week']=='week5']['T4'].min()
    Week5_Min_RH_4=df[df['week']=='week5']['RH_4'].min()
    Week5_Min_T5=df[df['week']=='week5']['T5'].min()
    Week5_Min_RH_5=df[df['week']=='week5']['RH_5'].min()
    Week5_Min_T6=df[df['week']=='week5']['T6'].min()
    Week5_Min_RH_6=df[df['week']=='week5']['RH_6'].min()
    Week5_Min_T7=df[df['week']=='week5']['T7'].min()
    Week5_Min_RH_7=df[df['week']=='week5']['RH_7'].min()
    Week5_Min_T8=df[df['week']=='week5']['T8'].min()
    Week5_Min_RH_8=df[df['week']=='week5']['RH_8'].min()
    Week5_Min_T9=df[df['week']=='week5']['T9'].min()
    Week5_Min_RH_9=df[df['week']=='week5']['RH_9'].min()
    Week5_Min_T_out=df[df['week']=='week5']['T_out'].min()
    Week5_Min_Press_mm_hg=df[df['week']=='week5']['Press_mm_hg'].min()
    Week5_Min_RH_out=df[df['week']=='week5']['RH_out'].min()
    Week5_Min_Windspeed=df[df['week']=='week5']['Windspeed'].min()
    Week5_Min_Visibility=df[df['week']=='week5']['Visibility'].min()
    Week5_Min_Tdewpoint=df[df['week']=='week5']['Tdewpoint'].min()
    
    data={'Month':moth,'Max_App':Max_App,'Max_light':Max_light,
           'Max_T1':Max_T1,'Max_RH_1':Max_RH_1,'Max_T2':Max_T2,'Max_RH_2':Max_RH_2,'Max_T3':Max_T3,'Max_RH_3':Max_RH_3,
           'Max_T4':Max_T4,'Max_RH_4':Max_RH_4,'Max_T5':Max_T5,'Max_RH_5':Max_RH_5,'Max_T6':Max_T6,'Max_RH_6':Max_RH_6,
           'Max_T7':Max_T7,'Max_RH_7':Max_RH_7,'Max_T8':Max_T8,'Max_RH_8':Max_RH_8,'Max_T9':Max_T9,'Max_RH_9':Max_RH_9,'Max_T_out':Max_T_out,
           'Max_Press_mm_hg':Max_Press_mm_hg,'Max_RH_out':Max_RH_out,'Max_Windspeed':Max_Windspeed,'Max_Visibility':Max_Visibility,
           'Max_Tdewpoint':Max_Tdewpoint,
           'Min_App':Min_App,'Min_light':Min_light,
           'Min_T1':Min_T1,'Min_RH_1':Min_RH_1,'Min_T2':Min_T2,'Min_RH_2':Min_RH_2,'Min_T3':Min_T3,'Min_RH_3':Min_RH_3,
           'Min_T4':Min_T4,'Min_RH_4':Min_RH_4,'Min_T5':Min_T5,'Min_RH_5':Min_RH_5,'Min_T6':Min_T6,'Min_RH_6':Min_RH_6,
           'Min_T7':Min_T7,'Min_RH_7':Min_RH_7,'Min_T8':Min_T8,'Min_RH_8':Min_RH_8,'Min_T9':Min_T9,'Min_RH_9':Min_RH_9,'Min_T_out':Min_T_out,
           'Min_Press_mm_hg':Min_Press_mm_hg,'Min_RH_out':Min_RH_out,'Min_Windspeed':Min_Windspeed,'Min_Visibility':Min_Visibility,
           'Min_Tdewpoint':Min_Tdewpoint,
                                      
           'Week1_Max_App':Week1_Max_App,'Week1_Max_light':Week1_Max_light,
           'Week1_Max_T1':Week1_Max_T1,'Week1_Max_RH_1':Week1_Max_RH_1,'Week1_Max_T2':Week1_Max_T2,'Week1_Max_RH_2':Week1_Max_RH_2,
           'Week1_Max_T3':Week1_Max_T3,'Week1_Max_RH_3':Week1_Max_RH_3,'Week1_Max_T4':Week1_Max_T4,'Week1_Max_RH_4':Week1_Max_RH_4,
           'Week1_Max_T5':Week1_Max_T5,'Week1_Max_RH_5':Week1_Max_RH_5,'Week1_Max_T6':Week1_Max_T6,'Week1_Max_RH_6':Week1_Max_RH_6,
           'Week1_Max_T7':Week1_Max_T7,'Week1_Max_RH_7':Week1_Max_RH_7,'Week1_Max_T8':Week1_Max_T8,'Week1_Max_RH_8':Week1_Max_RH_8,
           'Week1_Max_T9':Week1_Max_T9,'Week1_Max_RH_9':Week1_Max_RH_9,'Week1_Max_T_out':Week1_Max_T_out,'Week1_Max_Press_mm_hg':Week1_Max_Press_mm_hg,
           'Week1_Max_RH_out':Week1_Max_RH_out,'Week1_Max_Windspeed':Week1_Max_Windspeed,'Week1_Max_Visibility':Week1_Max_Visibility,
           'Week1_Max_Tdewpoint':Week1_Max_Tdewpoint,
           'Week1_Min_App':Week1_Min_App,'Week1_Min_light':Week1_Min_light,
           'Week1_Min_T1':Week1_Min_T1,'Week1_Min_RH_1':Week1_Min_RH_1,'Week1_Min_T2':Week1_Min_T2,'Week1_Min_RH_2':Week1_Min_RH_2,
           'Week1_Min_T3':Week1_Min_T3,'Week1_Min_RH_3':Week1_Min_RH_3,'Week1_Min_T4':Week1_Min_T4,'Week1_Min_RH_4':Week1_Min_RH_4,
           'Week1_Min_T5':Week1_Min_T5,'Week1_Min_RH_5':Week1_Min_RH_5,'Week1_Min_T6':Week1_Min_T6,'Week1_Min_RH_6':Week1_Min_RH_6,
           'Week1_Min_T7':Week1_Min_T7,'Week1_Min_RH_7':Week1_Min_RH_7,'Week1_Min_T8':Week1_Min_T8,'Week1_Min_RH_8':Week1_Min_RH_8,
           'Week1_Min_T9':Week1_Min_T9,'Week1_Min_RH_9':Week1_Min_RH_9,'Week1_Min_T_out':Week1_Min_T_out,'Week1_Min_Press_mm_hg':Week1_Min_Press_mm_hg,
           'Week1_Min_RH_out':Week1_Min_RH_out,'Week1_Min_Windspeed':Week1_Min_Windspeed,'Week1_Min_Visibility':Week1_Min_Visibility,
           'Week1_Min_Tdewpoint':Week1_Min_Tdewpoint,
             
           'Week2_Max_App':Week2_Max_App,'Week2_Max_light':Week2_Max_light,
           'Week2_Max_T1':Week2_Max_T1,'Week2_Max_RH_1':Week2_Max_RH_1,'Week2_Max_T2':Week2_Max_T2,'Week2_Max_RH_2':Week2_Max_RH_2,
           'Week2_Max_T3':Week2_Max_T3,'Week2_Max_RH_3':Week2_Max_RH_3,'Week2_Max_T4':Week2_Max_T4,'Week2_Max_RH_4':Week2_Max_RH_4,
           'Week2_Max_T5':Week2_Max_T5,'Week2_Max_RH_5':Week2_Max_RH_5,'Week2_Max_T6':Week2_Max_T6,'Week2_Max_RH_6':Week2_Max_RH_6,
           'Week2_Max_T7':Week2_Max_T7,'Week2_Max_RH_7':Week2_Max_RH_7,'Week2_Max_T8':Week2_Max_T8,'Week2_Max_RH_8':Week2_Max_RH_8,
           'Week2_Max_T9':Week2_Max_T9,'Week2_Max_RH_9':Week2_Max_RH_9,'Week2_Max_T_out':Week2_Max_T_out,'Week2_Max_Press_mm_hg':Week2_Max_Press_mm_hg,
           'Week2_Max_RH_out':Week2_Max_RH_out,'Week2_Max_Windspeed':Week2_Max_Windspeed,'Week2_Max_Visibility':Week2_Max_Visibility,
           'Week2_Max_Tdewpoint':Week2_Max_Tdewpoint,
           'Week2_Min_App':Week2_Min_App,'Week2_Min_light':Week2_Min_light,
           'Week2_Min_T1':Week2_Min_T1,'Week2_Min_RH_1':Week2_Min_RH_1,'Week2_Min_T2':Week2_Min_T2,'Week2_Min_RH_2':Week2_Min_RH_2,
           'Week2_Min_T3':Week2_Min_T3,'Week2_Min_RH_3':Week2_Min_RH_3,'Week2_Min_T4':Week2_Min_T4,'Week2_Min_RH_4':Week2_Min_RH_4,
           'Week2_Min_T5':Week2_Min_T5,'Week2_Min_RH_5':Week2_Min_RH_5,'Week2_Min_T6':Week2_Min_T6,'Week2_Min_RH_6':Week2_Min_RH_6,
           'Week2_Min_T7':Week2_Min_T7,'Week2_Min_RH_7':Week2_Min_RH_7,'Week2_Min_T8':Week2_Min_T8,'Week2_Min_RH_8':Week2_Min_RH_8,
           'Week2_Min_T9':Week2_Min_T9,'Week2_Min_RH_9':Week2_Min_RH_9,'Week2_Min_T_out':Week2_Min_T_out,'Week2_Min_Press_mm_hg':Week2_Min_Press_mm_hg,
           'Week2_Min_RH_out':Week2_Min_RH_out,'Week2_Min_Windspeed':Week2_Min_Windspeed,'Week2_Min_Visibility':Week2_Min_Visibility,
           'Week2_Min_Tdewpoint':Week2_Min_Tdewpoint,
         
           'Week3_Max_App':Week3_Max_App,'Week3_Max_light':Week3_Max_light,
           'Week3_Max_T1':Week3_Max_T1,'Week3_Max_RH_1':Week3_Max_RH_1,'Week3_Max_T2':Week3_Max_T2,'Week3_Max_RH_2':Week3_Max_RH_2,
           'Week3_Max_T3':Week3_Max_T3,'Week3_Max_RH_3':Week3_Max_RH_3,'Week3_Max_T4':Week3_Max_T4,'Week3_Max_RH_4':Week3_Max_RH_4,
           'Week3_Max_T5':Week3_Max_T5,'Week3_Max_RH_5':Week3_Max_RH_5,'Week3_Max_T6':Week3_Max_T6,'Week3_Max_RH_6':Week3_Max_RH_6,
           'Week3_Max_T7':Week3_Max_T7,'Week3_Max_RH_7':Week3_Max_RH_7,'Week3_Max_T8':Week3_Max_T8,'Week3_Max_RH_8':Week3_Max_RH_8,
           'Week3_Max_T9':Week3_Max_T9,'Week3_Max_RH_9':Week3_Max_RH_9,'Week3_Max_T_out':Week3_Max_T_out,'Week3_Max_Press_mm_hg':Week3_Max_Press_mm_hg,
           'Week3_Max_RH_out':Week3_Max_RH_out,'Week3_Max_Windspeed':Week3_Max_Windspeed,'Week3_Max_Visibility':Week3_Max_Visibility,
           'Week3_Max_Tdewpoint':Week3_Max_Tdewpoint,
           'Week3_Min_App':Week3_Min_App,'Week3_Min_light':Week3_Min_light,
           'Week3_Min_T1':Week3_Min_T1,'Week3_Min_RH_1':Week3_Min_RH_1,'Week3_Min_T2':Week3_Min_T2,'Week3_Min_RH_2':Week3_Min_RH_2,
           'Week3_Min_T3':Week3_Min_T3,'Week3_Min_RH_3':Week3_Min_RH_3,'Week3_Min_T4':Week3_Min_T4,'Week3_Min_RH_4':Week3_Min_RH_4,
           'Week3_Min_T5':Week3_Min_T5,'Week3_Min_RH_5':Week3_Min_RH_5,'Week3_Min_T6':Week3_Min_T6,'Week3_Min_RH_6':Week3_Min_RH_6,
           'Week3_Min_T7':Week3_Min_T7,'Week3_Min_RH_7':Week3_Min_RH_7,'Week3_Min_T8':Week3_Min_T8,'Week3_Min_RH_8':Week3_Min_RH_8,
           'Week3_Min_T9':Week3_Min_T9,'Week3_Min_RH_9':Week3_Min_RH_9,'Week3_Min_T_out':Week3_Min_T_out,'Week3_Min_Press_mm_hg':Week3_Min_Press_mm_hg,
           'Week3_Min_RH_out':Week3_Min_RH_out,'Week3_Min_Windspeed':Week3_Min_Windspeed,'Week3_Min_Visibility':Week3_Min_Visibility,
           'Week3_Min_Tdewpoint':Week3_Min_Tdewpoint,
         
           'Week4_Max_App':Week4_Max_App,'Week4_Max_light':Week4_Max_light,
           'Week4_Max_T1':Week4_Max_T1,'Week4_Max_RH_1':Week4_Max_RH_1,'Week4_Max_T2':Week4_Max_T2,'Week4_Max_RH_2':Week4_Max_RH_2,
           'Week4_Max_T3':Week4_Max_T3,'Week4_Max_RH_3':Week4_Max_RH_3,'Week4_Max_T4':Week4_Max_T4,'Week4_Max_RH_4':Week4_Max_RH_4,
           'Week4_Max_T5':Week4_Max_T5,'Week4_Max_RH_5':Week4_Max_RH_5,'Week4_Max_T6':Week4_Max_T6,'Week4_Max_RH_6':Week4_Max_RH_6,
           'Week4_Max_T7':Week4_Max_T7,'Week4_Max_RH_7':Week4_Max_RH_7,'Week4_Max_T8':Week4_Max_T8,'Week4_Max_RH_8':Week4_Max_RH_8,
           'Week4_Max_T9':Week4_Max_T9,'Week4_Max_RH_9':Week4_Max_RH_9,'Week4_Max_T_out':Week4_Max_T_out,'Week4_Max_Press_mm_hg':Week4_Max_Press_mm_hg,
           'Week4_Max_RH_out':Week4_Max_RH_out,'Week4_Max_Windspeed':Week4_Max_Windspeed,'Week4_Max_Visibility':Week4_Max_Visibility,
           'Week4_Max_Tdewpoint':Week4_Max_Tdewpoint,
           'Week4_Min_App':Week4_Min_App,'Week4_Min_light':Week4_Min_light,
           'Week4_Min_T1':Week4_Min_T1,'Week4_Min_RH_1':Week4_Min_RH_1,'Week4_Min_T2':Week4_Min_T2,'Week4_Min_RH_2':Week4_Min_RH_2,
           'Week4_Min_T3':Week4_Min_T3,'Week4_Min_RH_3':Week4_Min_RH_3,'Week4_Min_T4':Week4_Min_T4,'Week4_Min_RH_4':Week4_Min_RH_4,
           'Week4_Min_T5':Week4_Min_T5,'Week4_Min_RH_5':Week4_Min_RH_5,'Week4_Min_T6':Week4_Min_T6,'Week4_Min_RH_6':Week4_Min_RH_6,
           'Week4_Min_T7':Week4_Min_T7,'Week4_Min_RH_7':Week4_Min_RH_7,'Week4_Min_T8':Week4_Min_T8,'Week4_Min_RH_8':Week4_Min_RH_8,
           'Week4_Min_T9':Week4_Min_T9,'Week4_Min_RH_9':Week4_Min_RH_9,'Week4_Min_T_out':Week4_Min_T_out,'Week4_Min_Press_mm_hg':Week4_Min_Press_mm_hg,
           'Week4_Min_RH_out':Week4_Min_RH_out,'Week4_Min_Windspeed':Week4_Min_Windspeed,'Week4_Min_Visibility':Week4_Min_Visibility,
           'Week4_Min_Tdewpoint':Week4_Min_Tdewpoint,
         
           'Week5_Max_App':Week5_Max_App,'Week5_Max_light':Week5_Max_light,
           'Week5_Max_T1':Week5_Max_T1,'Week5_Max_RH_1':Week5_Max_RH_1,'Week5_Max_T2':Week5_Max_T2,'Week5_Max_RH_2':Week5_Max_RH_2,
           'Week5_Max_T3':Week5_Max_T3,'Week5_Max_RH_3':Week5_Max_RH_3,'Week5_Max_T4':Week5_Max_T4,'Week5_Max_RH_4':Week5_Max_RH_4,
           'Week5_Max_T5':Week5_Max_T5,'Week5_Max_RH_5':Week5_Max_RH_5,'Week5_Max_T6':Week5_Max_T6,'Week5_Max_RH_6':Week5_Max_RH_6,
           'Week5_Max_T7':Week5_Max_T7,'Week5_Max_RH_7':Week5_Max_RH_7,'Week5_Max_T8':Week5_Max_T8,'Week5_Max_RH_8':Week5_Max_RH_8,
           'Week5_Max_T9':Week5_Max_T9,'Week5_Max_RH_9':Week5_Max_RH_9,'Week5_Max_T_out':Week5_Max_T_out,'Week5_Max_Press_mm_hg':Week5_Max_Press_mm_hg,
           'Week5_Max_RH_out':Week5_Max_RH_out,'Week5_Max_Windspeed':Week5_Max_Windspeed,'Week5_Max_Visibility':Week5_Max_Visibility,
           'Week5_Max_Tdewpoint':Week5_Max_Tdewpoint,
           'Week5_Min_App':Week5_Min_App,'Week5_Min_light':Week5_Min_light,
           'Week5_Min_T1':Week5_Min_T1,'Week5_Min_RH_1':Week5_Min_RH_1,'Week5_Min_T2':Week5_Min_T2,'Week5_Min_RH_2':Week5_Min_RH_2,
           'Week5_Min_T3':Week5_Min_T3,'Week5_Min_RH_3':Week5_Min_RH_3,'Week5_Min_T4':Week5_Min_T4,'Week5_Min_RH_4':Week5_Min_RH_4,
           'Week5_Min_T5':Week5_Min_T5,'Week5_Min_RH_5':Week5_Min_RH_5,'Week5_Min_T6':Week5_Min_T6,'Week5_Min_RH_6':Week5_Min_RH_6,
           'Week5_Min_T7':Week5_Min_T7,'Week5_Min_RH_7':Week5_Min_RH_7,'Week5_Min_T8':Week5_Min_T8,'Week5_Min_RH_8':Week5_Min_RH_8,
           'Week5_Min_T9':Week5_Min_T9,'Week5_Min_RH_9':Week5_Min_RH_9,'Week5_Min_T_out':Week5_Min_T_out,'Week5_Min_Press_mm_hg':Week5_Min_Press_mm_hg,
           'Week5_Min_RH_out':Week5_Min_RH_out,'Week5_Min_Windspeed':Week5_Min_Windspeed,'Week5_Min_Visibility':Week5_Min_Visibility,
           'Week5_Min_Tdewpoint':Week5_Min_Tdewpoint}
    df_min_max_summ=df_min_max_summ.append(data,ignore_index=True)
    
df_summ.fillna(value=0, inplace=True)
df_min_max_summ.fillna(value=0, inplace=True)

# %% [markdown]
# Let's check what's in the two summary matrix

# %%
df_summ
# Out:
#   Month  Tot_Appliance  Avg_Appliance  Tot_light  Avg_light  Tot_Energy  \
# 0   Jan         283510      97.026010      13800   4.722793      297310
# 1   Feb         421550     100.945881      26490   6.343391      448040
# 2   Mar         432800      96.953405      17480   3.915771      450280
# 3   Apr         427200      98.888889      10440   2.416667      437640
# 4   May         362950      94.199325       6820   1.770049      369770
#
#    Avg_Energy    Mean_T1  Mean_RH_1    Mean_T2        ...         \
# 0  101.748802  19.945175  42.284480  19.102295        ...
# 1  107.289272  21.163817  41.010174  19.924704        ...
# 2  100.869176  21.259760  37.923927  19.141096        ...
# 3  101.305556  21.856511  39.722240  20.224405        ...
# 4   95.969375  23.877728  41.219759  23.253625        ...
#
#    Weekdays_Mean_T2  Weekdays_Mean_T3  Weekdays_Mean_light  Weekdays_Tot_App  \
# 0         18.860596         19.757401             3.741497          172450.0
# ...

# %%
df_min_max_summ
# Out:
#   Month  Max_App  Max_light     Max_T1   Max_RH_1     Max_T2   Max_RH_2  \
# 0   Jan     1080         70  23.790000  63.360000  22.790000  50.260000
# 1   Feb      770         50  24.100000  57.663333  23.600000  47.700000
# 2   Mar      880         50  23.700000  50.330000  22.856667  47.060000
# 3   Apr      900         30  23.666667  57.496667  24.600000  56.026667
# 4   May      850         30  26.260000  54.666667  29.856667  54.090000
#
#    Max_T3   Max_RH_3     Max_T4         ...           Week5_Min_T8  \
# 0  22.790  50.163333  22.463333         ...                  16.89
# 1  25.500  49.363333  23.760000         ...                  20.00
# 2  25.700  43.026667  23.200000         ...                  22.79
# 3  27.600  44.363333  23.760000         ...                  20.29
# 4  29.236  47.693333  26.200000         ...                   0.00
#
#    Week5_Min_RH_8  Week5_Min_T9  Week5_Min_RH_9  Week5_Min_T_out  \
# ...

# %% [markdown]
# Its better to save these dataframes in a 'csv' file which will make it easy for us to refer.

# %%
df_summ.to_csv('SumData.csv')
df_min_max_summ.to_csv('ExtremeData.csv')

# %% [markdown]
# # Analysis

# %% [markdown]
# How mean temperature are changing over course of time.

# %%
plt.rcParams['figure.figsize'] = (20, 8)
plt.plot(df_summ['Month'] , df_summ ['Mean_T1'] , label = 'Kitchen Area')
plt.plot(df_summ['Month'] , df_summ ['Mean_T2'] , label = 'Living Room')
plt.plot(df_summ['Month'] , df_summ ['Mean_T3'] , label = 'Laundry Room')
plt.plot(df_summ['Month'] , df_summ ['Mean_T4'] , label = 'Office Room')
plt.plot(df_summ['Month'] , df_summ ['Mean_T5'] , label = 'Bathroom')
plt.plot(df_summ['Month'] , df_summ ['Mean_T6'] , label = 'Outside the building')
plt.plot(df_summ['Month'] , df_summ ['Mean_T7'] , label = 'Ironing Room')
plt.plot(df_summ['Month'] , df_summ ['Mean_T8'] , label = 'Teenager Room')
plt.plot(df_summ['Month'] , df_summ ['Mean_T9'] , label = 'Parents Room')
plt.xlabel("Months" , fontsize=15)
plt.ylabel("Mean Temperature in ($^\circ$C)" , fontsize=15)
plt.title("Mean Temperature of every room for first 5 months" , fontsize=20)
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.legend()
plt.show()

# %% [markdown]
# How mean temperature is changing when comopared seperately

# %%
from matplotlib.ticker import NullFormatter  # useful for `logit` scale

# plot with various axes scales
plt.figure(1)

# T1
plt.subplot(331)
plt.plot(df_summ['Month'], df_summ['Mean_T1'])
plt.title('T1')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)


# T2
plt.subplot(332)
plt.plot(df_summ['Month'], df_summ['Mean_T2'])
plt.title('T2')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)


# T3
plt.subplot(333)
plt.plot(df_summ['Month'], df_summ['Mean_T3'])
plt.title('T3')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

# T4
plt.subplot(334)
plt.plot(df_summ['Month'], df_summ['Mean_T4'])
plt.title('T4')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T5
plt.subplot(335)
plt.plot(df_summ['Month'], df_summ['Mean_T5'])
plt.title('T5')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T6
plt.subplot(336)
plt.plot(df_summ['Month'], df_summ['Mean_T6'])
plt.title('T6')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T7
plt.subplot(337)
plt.plot(df_summ['Month'], df_summ['Mean_T7'])
plt.title('T7')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T8
plt.subplot(338)
plt.plot(df_summ['Month'], df_summ['Mean_T8'])
plt.title('T8')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T9
plt.subplot(339)
plt.plot(df_summ['Month'], df_summ['Mean_T9'])
plt.title('T9')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

plt.gca().yaxis.set_minor_formatter(NullFormatter())
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.35)

plt.show()

# %% [markdown]
# How mean humidity is changing over the course of time

# %%
plt.rcParams['figure.figsize'] = (20, 8)
plt.plot(df_summ['Month'] , df_summ ['Mean_RH_1'] , label = 'Kitchen Area')
plt.plot(df_summ['Month'] , df_summ ['Mean_RH_2'] , label = 'Living Room')
plt.plot(df_summ['Month'] , df_summ ['Mean_RH_3'] , label = 'Laundry Room')
plt.plot(df_summ['Month'] , df_summ ['Mean_RH_4'] , label = 'Office Room')
plt.plot(df_summ['Month'] , df_summ ['Mean_RH_5'] , label = 'Bathroom')
plt.plot(df_summ['Month'] , df_summ ['Mean_RH_6'] , label = 'Outside the building')
plt.plot(df_summ['Month'] , df_summ ['Mean_RH_7'] , label = 'Ironing Room')
plt.plot(df_summ['Month'] , df_summ ['Mean_RH_8'] , label = 'Teenager Room')
plt.plot(df_summ['Month'] , df_summ ['Mean_RH_9'] , label = 'Parents Room')
plt.xlabel("Months" , fontsize=15)
plt.ylabel("Mean Humidity in %" , fontsize=15)
plt.title("Mean Humidity of every room for first 5 months" , fontsize=20)
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.legend()
plt.show()

# %% [markdown]
# How mean Humidity changes over the course of time.

# %%
from matplotlib.ticker import NullFormatter  # useful for `logit` scale

# plot with various axes scales
plt.figure(1)

# T1
plt.subplot(331)
plt.plot(df_summ['Month'], df_summ['Mean_RH_1'])
plt.title('RH_1')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)


# T2
plt.subplot(332)
plt.plot(df_summ['Month'], df_summ['Mean_RH_2'])
plt.title('RH_2')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)


# T3
plt.subplot(333)
plt.plot(df_summ['Month'], df_summ['Mean_RH_3'])
plt.title('RH_3')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

# T4
plt.subplot(334)
plt.plot(df_summ['Month'], df_summ['Mean_RH_4'])
plt.title('RH_4')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T5
plt.subplot(335)
plt.plot(df_summ['Month'], df_summ['Mean_RH_5'])
plt.title('RH_5')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T6
plt.subplot(336)
plt.plot(df_summ['Month'], df_summ['Mean_RH_6'])
plt.title('RH_6')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T7
plt.subplot(337)
plt.plot(df_summ['Month'], df_summ['Mean_RH_7'])
plt.title('RH_7')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T8
plt.subplot(338)
plt.plot(df_summ['Month'], df_summ['Mean_RH_8'])
plt.title('RH_8')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T9
plt.subplot(339)
plt.plot(df_summ['Month'], df_summ['Mean_RH_9'])
plt.title('RH_9')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

plt.gca().yaxis.set_minor_formatter(NullFormatter())
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.35)

plt.show()

# %% [markdown]
# There are 6 other features present in dataset which are: Outside temperature, outside Pressure, outside Humidity, Windspeed, visibility and total dew point. Lets plot each of them in indiviual graphs to understand their characteristics.

# %%
plt.plot(df_summ['Month'] , df_summ ['Mean_T_out'] )
plt.xlabel("Months" , fontsize=18)
plt.ylabel("Mean Temperature in ($^\circ$C)" , fontsize=18)
plt.title("Mean Temperature outside (from Chièvres weather station)" , fontsize=20)
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.show()

# %%
plt.plot(df_summ['Month'] , df_summ ['Mean_Press_mm_hg']  , color = 'green')
plt.xlabel("Months" , fontsize=18)
plt.ylabel("Mean Pressure in mm Hg scale" , fontsize=18)
plt.title("Mean Pressure (from Chièvres weather station)" , fontsize=20)
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.show()

# %%
plt.plot(df_summ['Month'] , df_summ ['Mean_RH_out'] , color = 'red' )
plt.xlabel("Months" , fontsize=18)
plt.ylabel("Mean Humidity in %" , fontsize=18)
plt.title("Mean Humidity outside (from Chièvres weather station), in %" , fontsize=20)
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.show()

# %%
plt.plot(df_summ['Month'] , df_summ ['Mean_Windspeed'] , color = 'indigo' )
plt.xlabel("Months" , fontsize=18)
plt.ylabel("Mean windspeed in m/s" , fontsize=18)
plt.title("Mean Windspeed (from Chièvres weather station), in m/s", fontsize=20)
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.show()

# %%
plt.plot(df_summ['Month'] , df_summ ['Mean_Visibility'] , color = 'olive' )
plt.xlabel("Months" , fontsize=18)
plt.ylabel("Mean visibility in km" , fontsize=18)
plt.title("Mean Visibility (from Chièvres weather station), in km", fontsize=20)
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.show()

# %%
plt.plot(df_summ['Month'] , df_summ ['Mean_Tdewpoint'] , color = 'crimson' )
plt.xlabel("Months" , fontsize=18)
plt.ylabel("Mean dew point in °C" , fontsize=18)
plt.title("Mean dew point (from Chièvres weather station), °C", fontsize=20)
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.show()

# %% [markdown]
# We will now try to find the total consumption of energy by 'lights' and all the appliances at home.

# %%
from matplotlib.ticker import NullFormatter 

# plot with various axes scales
plt.figure(1)

# T1
plt.subplot(211)
plt.plot(df_summ['Month'], df_summ['Tot_Appliance'] ,  color = 'c')
plt.title('Appliance')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.ylabel("Total consumption in Wh" )
plt.xticks(x, y)
plt.grid(True)


# T2
plt.subplot(212)
plt.plot(df_summ['Month'], df_summ['Tot_light'] ,  color = 'g' )
plt.title('Light')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.ylabel("Total consumption in Wh" )
plt.xticks(x, y)
plt.grid(True)

plt.gca().yaxis.set_minor_formatter(NullFormatter())
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=0.92, bottom=0.08, left=0.10, right=0.95, hspace=0.25,
                    wspace=0.35)

plt.show()

# %% [markdown]
# We also try to find minimum and maximum values of temperature and humidity over the period of time.

# %%
from matplotlib.ticker import NullFormatter  # useful for `logit` scale

# plot with various axes scales
plt.figure(1)

# T1
plt.subplot(331)
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Max_T1'], label = 'Max')
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Min_T1'], label = 'Min')
plt.title('Kitchen')
x = df_min_max_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.legend()
plt.grid(True)


# T2
plt.subplot(332)
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Max_T2'], label = 'Max')
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Min_T2'], label = 'Min')
plt.legend()
plt.title('Living Room')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)


# T3
plt.subplot(333)
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Max_T3'], label = 'Max')
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Min_T3'], label = 'Min')
plt.legend()
plt.title('Laundry room')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

# T4
plt.subplot(334)
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Max_T4'], label = 'Max')
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Min_T4'], label = 'Min')
plt.legend()
plt.title('Office Room')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T5
plt.subplot(335)
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Max_T5'], label = 'Max')
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Min_T5'], label = 'Min')
plt.legend()
plt.title('Bathroom')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T6
plt.subplot(336)
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Max_T6'], label = 'Max')
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Min_T6'], label = 'Min')
plt.legend()
plt.title('Outside the building')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T7
plt.subplot(337)
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Max_T7'], label = 'Max')
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Min_T7'], label = 'Min')
plt.legend()
plt.title('Ironing room')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T8
plt.subplot(338)
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Max_T8'], label = 'Max')
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Min_T8'], label = 'Min')
plt.legend()
plt.title('Teenager Room')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T9
plt.subplot(339)
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Max_T9'], label = 'Max')
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Min_T9'], label = 'Min')
plt.legend()
plt.title('Parents Room')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

plt.gca().yaxis.set_minor_formatter(NullFormatter())
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=3, bottom=1, left=2, right=4, hspace=.75, wspace=.75 , aplha = 1)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-fbe8cedf0421> in <module>()
#     108 # Adjust the subplot layout, because the logit one may take more space
#     109 # than usual, due to y-tick labels like "1 - 10^{-3}"
# --> 110 plt.subplots_adjust(top=3, bottom=1, left=2, right=4, hspace=.75, wspace=.75 , aplha = 1)
#     111
#     112 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots_adjust(*args, **kwargs)
#    1275     """
#    1276     fig = gcf()
# -> 1277     fig.subplots_adjust(*args, **kwargs)
#    1278
#    1279
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in subplots_adjust(self, *args, **kwargs)
#    1859
#    1860         """
# -> 1861         self.subplotpars.update(*args, **kwargs)
#    1862         for ax in self.axes:
#    1863             if not isinstance(ax, SubplotBase):
#
# ...

# %%
from matplotlib.ticker import NullFormatter  # useful for `logit` scale

# plot with various axes scales
plt.figure(1)

# T1
plt.subplot(331)
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Max_RH_1'], label = 'Max')
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Min_RH_1'], label = 'Min')
plt.title('Kitchen')
x = df_min_max_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.legend()
plt.grid(True)


# T2
plt.subplot(332)
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Max_RH_2'], label = 'Max')
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Min_RH_2'], label = 'Min')
plt.legend()
plt.title('Living Room')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)


# T3
plt.subplot(333)
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Max_RH_3'], label = 'Max')
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Min_RH_3'], label = 'Min')
plt.legend()
plt.title('Laundry room')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

# T4
plt.subplot(334)
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Max_RH_4'], label = 'Max')
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Min_RH_4'], label = 'Min')
plt.legend()
plt.title('Office Room')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T5
plt.subplot(335)
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Max_RH_5'], label = 'Max')
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Min_RH_5'], label = 'Min')
plt.legend()
plt.title('Bathroom')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T6
plt.subplot(336)
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Max_RH_6'], label = 'Max')
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Min_RH_6'], label = 'Min')
plt.legend()
plt.title('Outside the building')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T7
plt.subplot(337)
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Max_RH_7'], label = 'Max')
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Min_RH_7'], label = 'Min')
plt.legend()
plt.title('Ironing room')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T8
plt.subplot(338)
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Max_RH_8'], label = 'Max')
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Min_RH_8'], label = 'Min')
plt.legend()
plt.title('Teenager Room')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

#T9
plt.subplot(339)
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Max_RH_9'], label = 'Max')
plt.plot(df_min_max_summ['Month'] , df_min_max_summ['Min_RH_9'], label = 'Min')
plt.legend()
plt.title('Parents Room')
x = df_summ['Month'].tolist()
y = ['Jan' , 'Feb' , 'Mar' , 'Apr' , 'May']
plt.xticks(x, y)
plt.grid(True)

plt.gca().yaxis.set_minor_formatter(NullFormatter())
# Adjust the subplot layout, because the logit one may take more space
# than usual, due to y-tick labels like "1 - 10^{-3}"
plt.subplots_adjust(top=3, bottom=1, left=2, right=4, hspace=.75, wspace=.75 , aplha = 1)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-565bb3935908> in <module>()
#     108 # Adjust the subplot layout, because the logit one may take more space
#     109 # than usual, due to y-tick labels like "1 - 10^{-3}"
# --> 110 plt.subplots_adjust(top=3, bottom=1, left=2, right=4, hspace=.75, wspace=.75 , aplha = 1)
#     111
#     112 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplots_adjust(*args, **kwargs)
#    1275     """
#    1276     fig = gcf()
# -> 1277     fig.subplots_adjust(*args, **kwargs)
#    1278
#    1279
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\figure.py in subplots_adjust(self, *args, **kwargs)
#    1859
#    1860         """
# -> 1861         self.subplotpars.update(*args, **kwargs)
#    1862         for ax in self.axes:
#    1863             if not isinstance(ax, SubplotBase):
#
# ...

# %% [markdown]
# A square plot representation of total energy consumption in the house over the period.

# %%
import squarify as sq
appliances_sum = df_summ['Tot_Appliance']
sq.plot(sizes= df_summ['Tot_Appliance'], label=["January", "Febuary", "March", "April" , "May"], color=["y","b","m", "k" , "g"], alpha=.6 )
plt.axis('off')
plt.show()

# %% [markdown]
# It is important to understand the change in mean of temperature with respect to others and over the period. So we are comparing mean of temperature in 3 rooms at one time with months.

# %%
plt.figure()
sns.pairplot(data = df_summ[["Month" , "Mean_T1" , "Mean_T2" , "Mean_T3"  ]]  , hue = 'Month')

# %%
plt.figure()
sns.pairplot(data = df_summ[["Month" , "Mean_T4" , "Mean_T5" , "Mean_T6"  ]]  , hue = 'Month')

# %%
plt.figure()
sns.pairplot(data = df_summ[["Month" , "Mean_T7" , "Mean_T8" , "Mean_T9"  ]]  , hue = 'Month')

# %% [markdown]
# Similarly, comparing the change in mean of humidity of 3 room at a time with respect to months.

# %%
plt.figure()
sns.pairplot(data = df_summ[["Month" , "Mean_RH_1" , "Mean_RH_2" , "Mean_RH_3" ]]  , hue = 'Month')

# %%
plt.figure()
sns.pairplot(data = df_summ[["Month" , "Mean_RH_4" , "Mean_RH_5" , "Mean_RH_6" ]]  , hue = 'Month')

# %%
plt.figure()
sns.pairplot(data = df_summ[["Month" , "Mean_RH_7" , "Mean_RH_8" , "Mean_RH_9" ]]  , hue = 'Month')

# %%
print(f['Appliances'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(f['Appliances'], color='g', bins=100, hist_kws={'alpha': 0.4});
# Out:
# count    19735.000000
# mean        97.694958
# std        102.524891
# min         10.000000
# 25%         50.000000
# 50%         60.000000
# 75%        100.000000
# max       1080.000000
# Name: Appliances, dtype: float64

# %% [markdown]
# Let's try to understand the pattern of change in mean temperature through a heat map.

# %%
a = df_summ[['Mean_T1','Mean_T2','Mean_T3','Mean_T4','Mean_T5','Mean_T6','Mean_T7','Mean_T8','Mean_T9']]


df = pd.DataFrame(a.T)
sns.heatmap(df)

plt.show()

# %% [markdown]
# When we see the above graphs of data, we can understand the pattern. Also we get a view of how the data is varying and which features would be important to be selected to run selected algorithms to get the desired data.
